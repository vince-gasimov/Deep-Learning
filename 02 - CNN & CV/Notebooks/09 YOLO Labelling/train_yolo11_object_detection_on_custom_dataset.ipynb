# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLO11 Object Detection on a Custom Dataset
#
# ---
#
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# YOLO11 builds on the advancements introduced in YOLOv9 and YOLOv10 earlier this year, incorporating improved architectural designs, enhanced feature extraction techniques, and optimized training methods.
#
# YOLO11m achieves a higher mean mAP score on the COCO dataset while using 22% fewer parameters than YOLOv8m, making it computationally lighter without sacrificing performance.
#
# YOLOv11 is available in 5 different sizes, ranging from `2.6M` to `56.9M` parameters, and capable of achieving from `39.5` to `54.7` mAP on the COCO dataset.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Configure API keys
#
# To fine-tune YOLO11, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑). Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# ### Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Fri Nov  8 11:38:06 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P0              31W /  70W |    243MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLO11 via Ultralytics

# %%
# %pip install ultralytics supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.4/112.6 GB disk)

# %% [markdown]
# ## Inference with model pre-trained on COCO dataset

# %% [markdown]
# ### CLI
#
# **NOTE:** CLI requires no customization or Python code. You can simply run all tasks from the terminal with the yolo command.

# %%
# !yolo task=detect mode=predict model=yolo11n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 95.9MB/s]
# WARNING ⚠️ yolo11n.pt appears to require 'dill', which is not in Ultralytics requirements.
# AutoInstall will run now for 'dill' but this feature will be removed in the future.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official Ultralytics model, i.e. 'yolo predict model=yolov8n.pt'
# requirements: Ultralytics requirement ['dill'] not found, attempting AutoUpdate...
# Collecting dill
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: dill
# Successfully installed dill-0.3.9
#
# requirements: AutoUpdate success ✅ 2.3s, installed 1 package: ['dill']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Ultralytics 8.3.2 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to 'dog.jpeg'...
# 100% 104k/104k [00:00<00:00, 44.7MB/s]
# image 1/1 /content/dog.jpeg: 640x384 2 persons, 1 car, 1 dog, 1 handbag, 61.4ms
# Speed: 11.7ms preprocess, 61.4ms inference, 773.5ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Result annotated image got saved in `{HOME}/runs/detect/predict/`. Let's display it.

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/dog.jpeg', width=600)

# %% [markdown]
# ### SDK
#
# **NOTE:** YOLO's Python interface allows for seamless integration into your Python projects, making it easy to load, run, and process the model's output.

# %%
from ultralytics import YOLO
from PIL import Image
import requests

model = YOLO('yolo11n.pt')
image = Image.open(requests.get('https://media.roboflow.com/notebooks/examples/dog.jpeg', stream=True).raw)
result = model.predict(image, conf=0.25)[0]
# Out:
# 0: 640x384 2 persons, 1 car, 1 dog, 1 handbag, 12.2ms
# Speed: 1.8ms preprocess, 12.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)

# %% [markdown]
# **NOTE:** The obtained `result` object stores information about the location, classes, and confidence levels of the detected objects.

# %%
result.boxes.xyxy
# Out:
# tensor([[3.0705e+02, 6.4341e+02, 5.2919e+02, 1.2558e+03],
#         [6.1400e+01, 2.4994e+02, 6.5165e+02, 9.7412e+02],
#         [1.7803e+00, 3.5551e+02, 6.3404e+02, 1.2788e+03],
#         [1.1933e+00, 3.5620e+02, 3.8455e+02, 1.2776e+03],
#         [6.2615e+02, 7.1818e+02, 6.9975e+02, 7.8754e+02]], device='cuda:0')

# %%
result.boxes.conf
# Out:
# tensor([0.6832, 0.6284, 0.5941, 0.3923, 0.3875], device='cuda:0')

# %%
result.boxes.cls
# Out:
# tensor([26., 16.,  0.,  0.,  2.], device='cuda:0')

# %% [markdown]
# **NOTE:** YOLO11 can be easily integrated with `supervision` using the familiar `from_ultralytics` connector.

# %%
import supervision as sv

detections = sv.Detections.from_ultralytics(result)

# %%
box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK)

annotated_image = image.copy()
annotated_image = box_annotator.annotate(annotated_image, detections=detections)
annotated_image = label_annotator.annotate(annotated_image, detections=detections)

sv.plot_image(annotated_image, size=(10, 10))

# %% [markdown]
# ## Fine-tune YOLO11 on custom dataset

# %% [markdown]
# **NOTE:** When training YOLOv11, make sure your data is located in `datasets`. If you'd like to change the default location of the data you want to use for fine-tuning, you can do so through Ultralytics' `settings.json`. In this tutorial, we will use one of the [datasets](https://universe.roboflow.com/liangdianzhong/-qvdww) available on [Roboflow Universe](https://universe.roboflow.com/). When downloading, make sure to select the `yolov11` export format.

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

from google.colab import userdata
from roboflow import Roboflow

rf = Roboflow(api_key="43CsIGAvcb8LQMD9UnJg")
project = rf.workspace("ismetgocer").project("windmills-bhea9")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# /content/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Windmills-1 to yolov11:: 100%|██████████| 734/734 [00:00<00:00, 3096.41it/s]
# Extracting Dataset Version Zip to Windmills-1 in yolov11:: 100%|██████████| 156/156 [00:00<00:00, 9043.45it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolo11s.pt data={dataset.location}/data.yaml epochs=10 imgsz=275 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11s.pt to 'yolo11s.pt'...
# 100% 18.4M/18.4M [00:00<00:00, 128MB/s]
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolo11s.pt, data=/content/datasets/Windmills-1/data.yaml, epochs=10, time=None, patience=100, batch=16, imgsz=275, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 21.7MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    819795  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# YOLO11s summary: 319 layers, 9,428,179 parameters, 9,428,163 gradients, 21.5 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# WARNING ⚠️ imgsz=[275] must be multiple of max stride 32, updating to [288]
# train: Scanning /content/datasets/Windmills-1/train/labels... 63 images, 0 backgrounds, 0 corrupt: 100% 63/63 [00:00<00:00, 1981.78it/s]
# train: New cache created: /content/datasets/Windmills-1/train/labels.cache
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Windmills-1/valid/labels... 6 images, 0 backgrounds, 0 corrupt: 100% 6/6 [00:00<00:00, 591.04it/s]
# val: New cache created: /content/datasets/Windmills-1/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 288 train, 288 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      1.15G      2.219      3.742      1.971         35        288: 100% 4/4 [00:02<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.36s/it]
#                    all          6          9    0.00358      0.667     0.0351     0.0114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      1.03G      2.283      3.661      2.012         33        288: 100% 4/4 [00:00<00:00,  5.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 18.72it/s]
#                    all          6          9      0.391      0.444      0.304      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      1.09G      1.704      2.309      1.549         40        288: 100% 4/4 [00:00<00:00,  6.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 18.64it/s]
#                    all          6          9      0.544          1      0.789      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      1.09G      1.432      1.605      1.401         35        288: 100% 4/4 [00:00<00:00,  6.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 19.42it/s]
#                    all          6          9       0.74      0.778      0.831      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      1.12G      1.299      1.257      1.314         35        288: 100% 4/4 [00:00<00:00,  7.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 17.82it/s]
#                    all          6          9      0.838      0.778      0.907      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      1.14G       1.26      1.103      1.287         30        288: 100% 4/4 [00:00<00:00,  5.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 14.90it/s]
#                    all          6          9       0.99      0.778      0.921      0.632
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      1.13G       1.29      1.051       1.24         32        288: 100% 4/4 [00:00<00:00,  4.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 11.38it/s]
#                    all          6          9      0.847      0.778      0.888      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      1.13G      1.219     0.9666      1.178         33        288: 100% 4/4 [00:00<00:00,  4.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 11.95it/s]
#                    all          6          9      0.965      0.778      0.934      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      1.13G      1.232     0.9441      1.205         30        288: 100% 4/4 [00:00<00:00,  7.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 20.37it/s]
#                    all          6          9      0.883      0.889       0.89      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      1.13G       1.18      0.846      1.153         31        288: 100% 4/4 [00:00<00:00,  7.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 16.80it/s]
#                    all          6          9      0.887      0.889      0.963      0.643
#
# 10 epochs completed in 0.008 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 19.1MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 19.1MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11s summary (fused): 238 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 20.33it/s]
#                    all          6          9      0.958      0.778      0.934      0.666
# Speed: 0.1ms preprocess, 3.6ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# **NOTE:** The results of the completed training are saved in `{HOME}/runs/detect/train/`. Let's examine them.

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					     labels.jpg    train_batch0.jpg
# confusion_matrix_normalized.png			     P_curve.png   train_batch1.jpg
# confusion_matrix.png				     PR_curve.png  train_batch2.jpg
# events.out.tfevents.1731066852.9512d0fbd485.12636.0  R_curve.png   val_batch0_labels.jpg
# F1_curve.png					     results.csv   val_batch0_pred.jpg
# labels_correlogram.jpg				     results.png   weights

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/results.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)

# %% [markdown]
# ## Validate fine-tuned model

# %%
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11s summary (fused): 238 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning /content/datasets/Windmills-1/valid/labels.cache... 6 images, 0 backgrounds, 0 corrupt: 100% 6/6 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.13it/s]
#                    all          6          9      0.957      0.778      0.934      0.679
# Speed: 0.1ms preprocess, 12.0ms inference, 0.0ms loss, 118.3ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with custom model

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/Windmills.mp4 save=True
# Out:
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11s summary (fused): 238 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# video 1/1 (frame 1/3384) /content/Windmills.mp4: 192x288 2 0s, 73.7ms
# video 1/1 (frame 2/3384) /content/Windmills.mp4: 192x288 2 0s, 10.4ms
# video 1/1 (frame 3/3384) /content/Windmills.mp4: 192x288 4 0s, 10.4ms
# video 1/1 (frame 4/3384) /content/Windmills.mp4: 192x288 3 0s, 10.1ms
# video 1/1 (frame 5/3384) /content/Windmills.mp4: 192x288 4 0s, 9.8ms
# video 1/1 (frame 6/3384) /content/Windmills.mp4: 192x288 4 0s, 9.1ms
# video 1/1 (frame 7/3384) /content/Windmills.mp4: 192x288 6 0s, 8.3ms
# video 1/1 (frame 8/3384) /content/Windmills.mp4: 192x288 6 0s, 10.2ms
# video 1/1 (frame 9/3384) /content/Windmills.mp4: 192x288 4 0s, 8.5ms
# video 1/1 (frame 10/3384) /content/Windmills.mp4: 192x288 3 0s, 12.5ms
# video 1/1 (frame 11/3384) /content/Windmills.mp4: 192x288 3 0s, 10.1ms
# video 1/1 (frame 12/3384) /content/Windmills.mp4: 192x288 2 0s, 9.0ms
# video 1/1 (frame 13/3384) /content/Windmills.mp4: 192x288 2 0s, 9.3ms
# video 1/1 (frame 14/3384) /content/Windmills.mp4: 192x288 2 0s, 9.6ms
# video 1/1 (frame 15/3384) /content/Windmills.mp4: 192x288 3 0s, 9.9ms
# video 1/1 (frame 16/3384) /content/Windmills.mp4: 192x288 3 0s, 8.8ms
# video 1/1 (frame 17/3384) /content/Windmills.mp4: 192x288 3 0s, 10.8ms
# video 1/1 (frame 18/3384) /content/Windmills.mp4: 192x288 3 0s, 13.4ms
# video 1/1 (frame 19/3384) /content/Windmills.mp4: 192x288 2 0s, 13.3ms
# video 1/1 (frame 20/3384) /content/Windmills.mp4: 192x288 2 0s, 9.8ms
# video 1/1 (frame 21/3384) /content/Windmills.mp4: 192x288 3 0s, 23.8ms
# video 1/1 (frame 22/3384) /content/Windmills.mp4: 192x288 3 0s, 12.0ms
# video 1/1 (frame 23/3384) /content/Windmills.mp4: 192x288 3 0s, 9.8ms
# video 1/1 (frame 24/3384) /content/Windmills.mp4: 192x288 3 0s, 10.1ms
# video 1/1 (frame 25/3384) /content/Windmills.mp4: 192x288 3 0s, 8.5ms
# video 1/1 (frame 26/3384) /content/Windmills.mp4: 192x288 3 0s, 9.9ms
# video 1/1 (frame 27/3384) /content/Windmills.mp4: 192x288 4 0s, 9.3ms
# video 1/1 (frame 28/3384) /content/Windmills.mp4: 192x288 3 0s, 12.4ms
# video 1/1 (frame 29/3384) /content/Windmills.mp4: 192x288 3 0s, 15.4ms
# video 1/1 (frame 30/3384) /content/Windmills.mp4: 192x288 4 0s, 15.0ms
# video 1/1 (frame 31/3384) /content/Windmills.mp4: 192x288 4 0s, 9.0ms
# video 1/1 (frame 32/3384) /content/Windmills.mp4: 192x288 4 0s, 9.2ms
# video 1/1 (frame 33/3384) /content/Windmills.mp4: 192x288 4 0s, 9.6ms
# video 1/1 (frame 34/3384) /content/Windmills.mp4: 192x288 3 0s, 9.4ms
# video 1/1 (frame 35/3384) /content/Windmills.mp4: 192x288 2 0s, 9.2ms
# video 1/1 (frame 36/3384) /content/Windmills.mp4: 192x288 2 0s, 10.5ms
# video 1/1 (frame 37/3384) /content/Windmills.mp4: 192x288 3 0s, 12.7ms
# video 1/1 (frame 38/3384) /content/Windmills.mp4: 192x288 3 0s, 11.1ms
# video 1/1 (frame 39/3384) /content/Windmills.mp4: 192x288 4 0s, 9.5ms
# video 1/1 (frame 40/3384) /content/Windmills.mp4: 192x288 3 0s, 9.2ms
# video 1/1 (frame 41/3384) /content/Windmills.mp4: 192x288 3 0s, 11.5ms
# video 1/1 (frame 42/3384) /content/Windmills.mp4: 192x288 4 0s, 13.0ms
# video 1/1 (frame 43/3384) /content/Windmills.mp4: 192x288 3 0s, 14.1ms
# video 1/1 (frame 44/3384) /content/Windmills.mp4: 192x288 3 0s, 14.1ms
# video 1/1 (frame 45/3384) /content/Windmills.mp4: 192x288 2 0s, 13.2ms
# video 1/1 (frame 46/3384) /content/Windmills.mp4: 192x288 2 0s, 10.7ms
# video 1/1 (frame 47/3384) /content/Windmills.mp4: 192x288 3 0s, 9.1ms
# video 1/1 (frame 48/3384) /content/Windmills.mp4: 192x288 2 0s, 12.8ms
# video 1/1 (frame 49/3384) /content/Windmills.mp4: 192x288 3 0s, 10.7ms
# video 1/1 (frame 50/3384) /content/Windmills.mp4: 192x288 2 0s, 11.0ms
# video 1/1 (frame 51/3384) /content/Windmills.mp4: 192x288 4 0s, 10.5ms
# video 1/1 (frame 52/3384) /content/Windmills.mp4: 192x288 2 0s, 10.2ms
# video 1/1 (frame 53/3384) /content/Windmills.mp4: 192x288 2 0s, 9.3ms
# video 1/1 (frame 54/3384) /content/Windmills.mp4: 192x288 3 0s, 9.7ms
# video 1/1 (frame 55/3384) /content/Windmills.mp4: 192x288 5 0s, 8.7ms
# video 1/1 (frame 56/3384) /content/Windmills.mp4: 192x288 5 0s, 9.7ms
# video 1/1 (frame 57/3384) /content/Windmills.mp4: 192x288 4 0s, 11.8ms
# video 1/1 (frame 58/3384) /content/Windmills.mp4: 192x288 4 0s, 10.6ms
# video 1/1 (frame 59/3384) /content/Windmills.mp4: 192x288 5 0s, 9.3ms
# video 1/1 (frame 60/3384) /content/Windmills.mp4: 192x288 4 0s, 9.3ms
# video 1/1 (frame 61/3384) /content/Windmills.mp4: 192x288 2 0s, 10.1ms
# video 1/1 (frame 62/3384) /content/Windmills.mp4: 192x288 2 0s, 18.0ms
# video 1/1 (frame 63/3384) /content/Windmills.mp4: 192x288 5 0s, 21.1ms
# video 1/1 (frame 64/3384) /content/Windmills.mp4: 192x288 3 0s, 20.1ms
# video 1/1 (frame 65/3384) /content/Windmills.mp4: 192x288 4 0s, 15.9ms
# video 1/1 (frame 66/3384) /content/Windmills.mp4: 192x288 4 0s, 14.4ms
# video 1/1 (frame 67/3384) /content/Windmills.mp4: 192x288 3 0s, 12.7ms
# video 1/1 (frame 68/3384) /content/Windmills.mp4: 192x288 3 0s, 10.8ms
# video 1/1 (frame 69/3384) /content/Windmills.mp4: 192x288 3 0s, 26.6ms
# video 1/1 (frame 70/3384) /content/Windmills.mp4: 192x288 3 0s, 17.7ms
# video 1/1 (frame 71/3384) /content/Windmills.mp4: 192x288 2 0s, 12.6ms
# video 1/1 (frame 72/3384) /content/Windmills.mp4: 192x288 2 0s, 13.4ms
# video 1/1 (frame 73/3384) /content/Windmills.mp4: 192x288 3 0s, 12.1ms
# video 1/1 (frame 74/3384) /content/Windmills.mp4: 192x288 3 0s, 18.3ms
# video 1/1 (frame 75/3384) /content/Windmills.mp4: 192x288 3 0s, 15.8ms
# video 1/1 (frame 76/3384) /content/Windmills.mp4: 192x288 3 0s, 15.6ms
# video 1/1 (frame 77/3384) /content/Windmills.mp4: 192x288 2 0s, 14.3ms
# video 1/1 (frame 78/3384) /content/Windmills.mp4: 192x288 4 0s, 13.1ms
# video 1/1 (frame 79/3384) /content/Windmills.mp4: 192x288 5 0s, 11.8ms
# video 1/1 (frame 80/3384) /content/Windmills.mp4: 192x288 5 0s, 11.7ms
# video 1/1 (frame 81/3384) /content/Windmills.mp4: 192x288 4 0s, 11.6ms
# video 1/1 (frame 82/3384) /content/Windmills.mp4: 192x288 5 0s, 18.6ms
# video 1/1 (frame 83/3384) /content/Windmills.mp4: 192x288 3 0s, 11.1ms
# video 1/1 (frame 84/3384) /content/Windmills.mp4: 192x288 4 0s, 14.0ms
# video 1/1 (frame 85/3384) /content/Windmills.mp4: 192x288 3 0s, 12.0ms
# video 1/1 (frame 86/3384) /content/Windmills.mp4: 192x288 4 0s, 11.6ms
# video 1/1 (frame 87/3384) /content/Windmills.mp4: 192x288 3 0s, 11.5ms
# video 1/1 (frame 88/3384) /content/Windmills.mp4: 192x288 5 0s, 13.7ms
# video 1/1 (frame 89/3384) /content/Windmills.mp4: 192x288 4 0s, 14.5ms
# video 1/1 (frame 90/3384) /content/Windmills.mp4: 192x288 5 0s, 15.8ms
# video 1/1 (frame 91/3384) /content/Windmills.mp4: 192x288 4 0s, 16.1ms
# video 1/1 (frame 92/3384) /content/Windmills.mp4: 192x288 4 0s, 11.0ms
# video 1/1 (frame 93/3384) /content/Windmills.mp4: 192x288 3 0s, 15.5ms
# video 1/1 (frame 94/3384) /content/Windmills.mp4: 192x288 4 0s, 17.2ms
# video 1/1 (frame 95/3384) /content/Windmills.mp4: 192x288 4 0s, 16.2ms
# video 1/1 (frame 96/3384) /content/Windmills.mp4: 192x288 7 0s, 11.5ms
# video 1/1 (frame 97/3384) /content/Windmills.mp4: 192x288 3 0s, 11.3ms
# video 1/1 (frame 98/3384) /content/Windmills.mp4: 192x288 3 0s, 13.4ms
# video 1/1 (frame 99/3384) /content/Windmills.mp4: 192x288 3 0s, 16.3ms
# video 1/1 (frame 100/3384) /content/Windmills.mp4: 192x288 2 0s, 10.9ms
# video 1/1 (frame 101/3384) /content/Windmills.mp4: 192x288 3 0s, 10.7ms
# video 1/1 (frame 102/3384) /content/Windmills.mp4: 192x288 1 0, 12.3ms
# video 1/1 (frame 103/3384) /content/Windmills.mp4: 192x288 2 0s, 11.4ms
# video 1/1 (frame 104/3384) /content/Windmills.mp4: 192x288 1 0, 11.2ms
# video 1/1 (frame 105/3384) /content/Windmills.mp4: 192x288 2 0s, 10.8ms
# video 1/1 (frame 106/3384) /content/Windmills.mp4: 192x288 3 0s, 18.4ms
# video 1/1 (frame 107/3384) /content/Windmills.mp4: 192x288 3 0s, 20.3ms
# video 1/1 (frame 108/3384) /content/Windmills.mp4: 192x288 3 0s, 22.3ms
# video 1/1 (frame 109/3384) /content/Windmills.mp4: 192x288 3 0s, 16.0ms
# video 1/1 (frame 110/3384) /content/Windmills.mp4: 192x288 2 0s, 13.2ms
# video 1/1 (frame 111/3384) /content/Windmills.mp4: 192x288 1 0, 14.4ms
# video 1/1 (frame 112/3384) /content/Windmills.mp4: 192x288 2 0s, 15.3ms
# video 1/1 (frame 113/3384) /content/Windmills.mp4: 192x288 2 0s, 18.2ms
# video 1/1 (frame 114/3384) /content/Windmills.mp4: 192x288 1 0, 11.1ms
# video 1/1 (frame 115/3384) /content/Windmills.mp4: 192x288 3 0s, 11.0ms
# video 1/1 (frame 116/3384) /content/Windmills.mp4: 192x288 3 0s, 15.9ms
# video 1/1 (frame 117/3384) /content/Windmills.mp4: 192x288 2 0s, 19.9ms
# video 1/1 (frame 118/3384) /content/Windmills.mp4: 192x288 2 0s, 20.4ms
# video 1/1 (frame 119/3384) /content/Windmills.mp4: 192x288 2 0s, 17.4ms
# video 1/1 (frame 120/3384) /content/Windmills.mp4: 192x288 2 0s, 21.7ms
# video 1/1 (frame 121/3384) /content/Windmills.mp4: 192x288 2 0s, 19.4ms
# video 1/1 (frame 122/3384) /content/Windmills.mp4: 192x288 2 0s, 13.8ms
# video 1/1 (frame 123/3384) /content/Windmills.mp4: 192x288 2 0s, 15.9ms
# video 1/1 (frame 124/3384) /content/Windmills.mp4: 192x288 2 0s, 14.1ms
# video 1/1 (frame 125/3384) /content/Windmills.mp4: 192x288 3 0s, 13.3ms
# video 1/1 (frame 126/3384) /content/Windmills.mp4: 192x288 2 0s, 12.1ms
# video 1/1 (frame 127/3384) /content/Windmills.mp4: 192x288 1 0, 17.2ms
# video 1/1 (frame 128/3384) /content/Windmills.mp4: 192x288 1 0, 15.7ms
# video 1/1 (frame 129/3384) /content/Windmills.mp4: 192x288 1 0, 11.4ms
# video 1/1 (frame 130/3384) /content/Windmills.mp4: 192x288 1 0, 16.1ms
# video 1/1 (frame 131/3384) /content/Windmills.mp4: 192x288 2 0s, 12.0ms
# video 1/1 (frame 132/3384) /content/Windmills.mp4: 192x288 2 0s, 13.5ms
# video 1/1 (frame 133/3384) /content/Windmills.mp4: 192x288 2 0s, 14.2ms
# video 1/1 (frame 134/3384) /content/Windmills.mp4: 192x288 2 0s, 12.5ms
# video 1/1 (frame 135/3384) /content/Windmills.mp4: 192x288 2 0s, 14.0ms
# video 1/1 (frame 136/3384) /content/Windmills.mp4: 192x288 2 0s, 17.6ms
# video 1/1 (frame 137/3384) /content/Windmills.mp4: 192x288 3 0s, 21.5ms
# video 1/1 (frame 138/3384) /content/Windmills.mp4: 192x288 1 0, 18.8ms
# video 1/1 (frame 139/3384) /content/Windmills.mp4: 192x288 2 0s, 15.0ms
# video 1/1 (frame 140/3384) /content/Windmills.mp4: 192x288 2 0s, 16.3ms
# video 1/1 (frame 141/3384) /content/Windmills.mp4: 192x288 2 0s, 16.6ms
# video 1/1 (frame 142/3384) /content/Windmills.mp4: 192x288 3 0s, 21.7ms
# video 1/1 (frame 143/3384) /content/Windmills.mp4: 192x288 2 0s, 20.8ms
# video 1/1 (frame 144/3384) /content/Windmills.mp4: 192x288 2 0s, 12.5ms
# video 1/1 (frame 145/3384) /content/Windmills.mp4: 192x288 2 0s, 20.9ms
# video 1/1 (frame 146/3384) /content/Windmills.mp4: 192x288 2 0s, 14.6ms
# video 1/1 (frame 147/3384) /content/Windmills.mp4: 192x288 2 0s, 15.0ms
# video 1/1 (frame 148/3384) /content/Windmills.mp4: 192x288 2 0s, 15.2ms
# video 1/1 (frame 149/3384) /content/Windmills.mp4: 192x288 2 0s, 17.5ms
# video 1/1 (frame 150/3384) /content/Windmills.mp4: 192x288 2 0s, 16.2ms
# video 1/1 (frame 151/3384) /content/Windmills.mp4: 192x288 2 0s, 12.6ms
# video 1/1 (frame 152/3384) /content/Windmills.mp4: 192x288 2 0s, 13.7ms
# video 1/1 (frame 153/3384) /content/Windmills.mp4: 192x288 2 0s, 9.4ms
# video 1/1 (frame 154/3384) /content/Windmills.mp4: 192x288 1 0, 9.8ms
# video 1/1 (frame 155/3384) /content/Windmills.mp4: 192x288 2 0s, 9.0ms
# video 1/1 (frame 156/3384) /content/Windmills.mp4: 192x288 1 0, 10.1ms
# video 1/1 (frame 157/3384) /content/Windmills.mp4: 192x288 2 0s, 9.0ms
# video 1/1 (frame 158/3384) /content/Windmills.mp4: 192x288 3 0s, 9.6ms
# video 1/1 (frame 159/3384) /content/Windmills.mp4: 192x288 2 0s, 10.8ms
# video 1/1 (frame 160/3384) /content/Windmills.mp4: 192x288 3 0s, 11.2ms
# video 1/1 (frame 161/3384) /content/Windmills.mp4: 192x288 1 0, 9.4ms
# video 1/1 (frame 162/3384) /content/Windmills.mp4: 192x288 2 0s, 10.2ms
# video 1/1 (frame 163/3384) /content/Windmills.mp4: 192x288 3 0s, 9.1ms
# video 1/1 (frame 164/3384) /content/Windmills.mp4: 192x288 3 0s, 11.4ms
# video 1/1 (frame 165/3384) /content/Windmills.mp4: 192x288 2 0s, 10.9ms
# video 1/1 (frame 166/3384) /content/Windmills.mp4: 192x288 1 0, 9.6ms
# video 1/1 (frame 167/3384) /content/Windmills.mp4: 192x288 1 0, 11.2ms
# video 1/1 (frame 168/3384) /content/Windmills.mp4: 192x288 2 0s, 13.6ms
# video 1/1 (frame 169/3384) /content/Windmills.mp4: 192x288 4 0s, 8.8ms
# video 1/1 (frame 170/3384) /content/Windmills.mp4: 192x288 3 0s, 9.1ms
# video 1/1 (frame 171/3384) /content/Windmills.mp4: 192x288 2 0s, 10.3ms
# video 1/1 (frame 172/3384) /content/Windmills.mp4: 192x288 3 0s, 10.7ms
# video 1/1 (frame 173/3384) /content/Windmills.mp4: 192x288 2 0s, 17.3ms
# video 1/1 (frame 174/3384) /content/Windmills.mp4: 192x288 2 0s, 8.9ms
# video 1/1 (frame 175/3384) /content/Windmills.mp4: 192x288 2 0s, 10.2ms
# video 1/1 (frame 176/3384) /content/Windmills.mp4: 192x288 2 0s, 10.5ms
# video 1/1 (frame 177/3384) /content/Windmills.mp4: 192x288 2 0s, 9.3ms
# video 1/1 (frame 178/3384) /content/Windmills.mp4: 192x288 2 0s, 9.4ms
# video 1/1 (frame 179/3384) /content/Windmills.mp4: 192x288 2 0s, 12.2ms
# video 1/1 (frame 180/3384) /content/Windmills.mp4: 192x288 2 0s, 10.2ms
# video 1/1 (frame 181/3384) /content/Windmills.mp4: 192x288 2 0s, 8.6ms
# video 1/1 (frame 182/3384) /content/Windmills.mp4: 192x288 2 0s, 9.1ms
# video 1/1 (frame 183/3384) /content/Windmills.mp4: 192x288 1 0, 9.4ms
# video 1/1 (frame 184/3384) /content/Windmills.mp4: 192x288 1 0, 9.3ms
# video 1/1 (frame 185/3384) /content/Windmills.mp4: 192x288 2 0s, 8.6ms
# video 1/1 (frame 186/3384) /content/Windmills.mp4: 192x288 2 0s, 9.0ms
# video 1/1 (frame 187/3384) /content/Windmills.mp4: 192x288 2 0s, 9.7ms
# video 1/1 (frame 188/3384) /content/Windmills.mp4: 192x288 2 0s, 9.0ms
# video 1/1 (frame 189/3384) /content/Windmills.mp4: 192x288 2 0s, 17.3ms
# video 1/1 (frame 190/3384) /content/Windmills.mp4: 192x288 2 0s, 8.5ms
# video 1/1 (frame 191/3384) /content/Windmills.mp4: 192x288 2 0s, 10.2ms
# video 1/1 (frame 192/3384) /content/Windmills.mp4: 192x288 2 0s, 8.2ms
# video 1/1 (frame 193/3384) /content/Windmills.mp4: 192x288 1 0, 11.2ms
# video 1/1 (frame 194/3384) /content/Windmills.mp4: 192x288 1 0, 15.4ms
# video 1/1 (frame 195/3384) /content/Windmills.mp4: 192x288 1 0, 11.4ms
# video 1/1 (frame 196/3384) /content/Windmills.mp4: 192x288 1 0, 11.0ms
# video 1/1 (frame 197/3384) /content/Windmills.mp4: 192x288 1 0, 9.4ms
# video 1/1 (frame 198/3384) /content/Windmills.mp4: 192x288 2 0s, 8.9ms
# video 1/1 (frame 199/3384) /content/Windmills.mp4: 192x288 1 0, 21.5ms
# video 1/1 (frame 200/3384) /content/Windmills.mp4: 192x288 1 0, 13.1ms
# video 1/1 (frame 201/3384) /content/Windmills.mp4: 192x288 1 0, 11.0ms
# video 1/1 (frame 202/3384) /content/Windmills.mp4: 192x288 2 0s, 12.9ms
# video 1/1 (frame 203/3384) /content/Windmills.mp4: 192x288 2 0s, 12.2ms
# video 1/1 (frame 204/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 205/3384) /content/Windmills.mp4: 192x288 2 0s, 8.3ms
# video 1/1 (frame 206/3384) /content/Windmills.mp4: 192x288 2 0s, 12.5ms
# video 1/1 (frame 207/3384) /content/Windmills.mp4: 192x288 2 0s, 11.2ms
# video 1/1 (frame 208/3384) /content/Windmills.mp4: 192x288 2 0s, 9.2ms
# video 1/1 (frame 209/3384) /content/Windmills.mp4: 192x288 2 0s, 10.2ms
# video 1/1 (frame 210/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 211/3384) /content/Windmills.mp4: 192x288 1 0, 8.8ms
# video 1/1 (frame 212/3384) /content/Windmills.mp4: 192x288 1 0, 13.1ms
# video 1/1 (frame 213/3384) /content/Windmills.mp4: 192x288 1 0, 9.0ms
# video 1/1 (frame 214/3384) /content/Windmills.mp4: 192x288 1 0, 13.6ms
# video 1/1 (frame 215/3384) /content/Windmills.mp4: 192x288 1 0, 8.7ms
# video 1/1 (frame 216/3384) /content/Windmills.mp4: 192x288 2 0s, 16.5ms
# video 1/1 (frame 217/3384) /content/Windmills.mp4: 192x288 2 0s, 17.6ms
# video 1/1 (frame 218/3384) /content/Windmills.mp4: 192x288 2 0s, 9.5ms
# video 1/1 (frame 219/3384) /content/Windmills.mp4: 192x288 2 0s, 9.1ms
# video 1/1 (frame 220/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 221/3384) /content/Windmills.mp4: 192x288 2 0s, 8.4ms
# video 1/1 (frame 222/3384) /content/Windmills.mp4: 192x288 3 0s, 8.8ms
# video 1/1 (frame 223/3384) /content/Windmills.mp4: 192x288 1 0, 8.3ms
# video 1/1 (frame 224/3384) /content/Windmills.mp4: 192x288 1 0, 9.0ms
# video 1/1 (frame 225/3384) /content/Windmills.mp4: 192x288 1 0, 11.6ms
# video 1/1 (frame 226/3384) /content/Windmills.mp4: 192x288 3 0s, 10.7ms
# video 1/1 (frame 227/3384) /content/Windmills.mp4: 192x288 2 0s, 10.2ms
# video 1/1 (frame 228/3384) /content/Windmills.mp4: 192x288 3 0s, 8.7ms
# video 1/1 (frame 229/3384) /content/Windmills.mp4: 192x288 1 0, 8.8ms
# video 1/1 (frame 230/3384) /content/Windmills.mp4: 192x288 2 0s, 9.7ms
# video 1/1 (frame 231/3384) /content/Windmills.mp4: 192x288 2 0s, 9.1ms
# video 1/1 (frame 232/3384) /content/Windmills.mp4: 192x288 2 0s, 9.0ms
# video 1/1 (frame 233/3384) /content/Windmills.mp4: 192x288 2 0s, 9.2ms
# video 1/1 (frame 234/3384) /content/Windmills.mp4: 192x288 2 0s, 18.2ms
# video 1/1 (frame 235/3384) /content/Windmills.mp4: 192x288 2 0s, 23.3ms
# video 1/1 (frame 236/3384) /content/Windmills.mp4: 192x288 3 0s, 14.9ms
# video 1/1 (frame 237/3384) /content/Windmills.mp4: 192x288 3 0s, 11.8ms
# video 1/1 (frame 238/3384) /content/Windmills.mp4: 192x288 6 0s, 9.7ms
# video 1/1 (frame 239/3384) /content/Windmills.mp4: 192x288 4 0s, 14.9ms
# video 1/1 (frame 240/3384) /content/Windmills.mp4: 192x288 3 0s, 11.1ms
# video 1/1 (frame 241/3384) /content/Windmills.mp4: 192x288 2 0s, 11.2ms
# video 1/1 (frame 242/3384) /content/Windmills.mp4: 192x288 4 0s, 9.0ms
# video 1/1 (frame 243/3384) /content/Windmills.mp4: 192x288 4 0s, 10.1ms
# video 1/1 (frame 244/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 245/3384) /content/Windmills.mp4: 192x288 2 0s, 12.0ms
# video 1/1 (frame 246/3384) /content/Windmills.mp4: 192x288 3 0s, 9.9ms
# video 1/1 (frame 247/3384) /content/Windmills.mp4: 192x288 5 0s, 9.6ms
# video 1/1 (frame 248/3384) /content/Windmills.mp4: 192x288 4 0s, 9.6ms
# video 1/1 (frame 249/3384) /content/Windmills.mp4: 192x288 4 0s, 10.5ms
# video 1/1 (frame 250/3384) /content/Windmills.mp4: 192x288 3 0s, 9.0ms
# video 1/1 (frame 251/3384) /content/Windmills.mp4: 192x288 3 0s, 11.2ms
# video 1/1 (frame 252/3384) /content/Windmills.mp4: 192x288 3 0s, 15.7ms
# video 1/1 (frame 253/3384) /content/Windmills.mp4: 192x288 3 0s, 14.9ms
# video 1/1 (frame 254/3384) /content/Windmills.mp4: 192x288 2 0s, 9.4ms
# video 1/1 (frame 255/3384) /content/Windmills.mp4: 192x288 2 0s, 11.1ms
# video 1/1 (frame 256/3384) /content/Windmills.mp4: 192x288 1 0, 12.3ms
# video 1/1 (frame 257/3384) /content/Windmills.mp4: 192x288 3 0s, 10.0ms
# video 1/1 (frame 258/3384) /content/Windmills.mp4: 192x288 3 0s, 10.1ms
# video 1/1 (frame 259/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 260/3384) /content/Windmills.mp4: 192x288 3 0s, 17.8ms
# video 1/1 (frame 261/3384) /content/Windmills.mp4: 192x288 3 0s, 12.0ms
# video 1/1 (frame 262/3384) /content/Windmills.mp4: 192x288 3 0s, 11.0ms
# video 1/1 (frame 263/3384) /content/Windmills.mp4: 192x288 2 0s, 9.1ms
# video 1/1 (frame 264/3384) /content/Windmills.mp4: 192x288 2 0s, 11.9ms
# video 1/1 (frame 265/3384) /content/Windmills.mp4: 192x288 3 0s, 11.8ms
# video 1/1 (frame 266/3384) /content/Windmills.mp4: 192x288 2 0s, 11.5ms
# video 1/1 (frame 267/3384) /content/Windmills.mp4: 192x288 2 0s, 22.5ms
# video 1/1 (frame 268/3384) /content/Windmills.mp4: 192x288 2 0s, 8.7ms
# video 1/1 (frame 269/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 270/3384) /content/Windmills.mp4: 192x288 2 0s, 9.1ms
# video 1/1 (frame 271/3384) /content/Windmills.mp4: 192x288 2 0s, 9.1ms
# video 1/1 (frame 272/3384) /content/Windmills.mp4: 192x288 2 0s, 8.7ms
# video 1/1 (frame 273/3384) /content/Windmills.mp4: 192x288 3 0s, 8.5ms
# video 1/1 (frame 274/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 275/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 276/3384) /content/Windmills.mp4: 192x288 3 0s, 8.5ms
# video 1/1 (frame 277/3384) /content/Windmills.mp4: 192x288 3 0s, 10.9ms
# video 1/1 (frame 278/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 279/3384) /content/Windmills.mp4: 192x288 2 0s, 13.4ms
# video 1/1 (frame 280/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 281/3384) /content/Windmills.mp4: 192x288 2 0s, 8.2ms
# video 1/1 (frame 282/3384) /content/Windmills.mp4: 192x288 2 0s, 20.5ms
# video 1/1 (frame 283/3384) /content/Windmills.mp4: 192x288 2 0s, 18.6ms
# video 1/1 (frame 284/3384) /content/Windmills.mp4: 192x288 2 0s, 10.8ms
# video 1/1 (frame 285/3384) /content/Windmills.mp4: 192x288 2 0s, 9.7ms
# video 1/1 (frame 286/3384) /content/Windmills.mp4: 192x288 2 0s, 9.5ms
# video 1/1 (frame 287/3384) /content/Windmills.mp4: 192x288 2 0s, 8.7ms
# video 1/1 (frame 288/3384) /content/Windmills.mp4: 192x288 2 0s, 8.6ms
# video 1/1 (frame 289/3384) /content/Windmills.mp4: 192x288 2 0s, 8.9ms
# video 1/1 (frame 290/3384) /content/Windmills.mp4: 192x288 2 0s, 8.4ms
# video 1/1 (frame 291/3384) /content/Windmills.mp4: 192x288 2 0s, 9.7ms
# video 1/1 (frame 292/3384) /content/Windmills.mp4: 192x288 2 0s, 10.4ms
# video 1/1 (frame 293/3384) /content/Windmills.mp4: 192x288 2 0s, 9.1ms
# video 1/1 (frame 294/3384) /content/Windmills.mp4: 192x288 2 0s, 8.7ms
# video 1/1 (frame 295/3384) /content/Windmills.mp4: 192x288 2 0s, 8.7ms
# video 1/1 (frame 296/3384) /content/Windmills.mp4: 192x288 3 0s, 8.8ms
# video 1/1 (frame 297/3384) /content/Windmills.mp4: 192x288 3 0s, 8.8ms
# video 1/1 (frame 298/3384) /content/Windmills.mp4: 192x288 2 0s, 8.5ms
# video 1/1 (frame 299/3384) /content/Windmills.mp4: 192x288 2 0s, 9.6ms
# video 1/1 (frame 300/3384) /content/Windmills.mp4: 192x288 2 0s, 13.5ms
# video 1/1 (frame 301/3384) /content/Windmills.mp4: 192x288 2 0s, 11.7ms
# video 1/1 (frame 302/3384) /content/Windmills.mp4: 192x288 2 0s, 11.2ms
# video 1/1 (frame 303/3384) /content/Windmills.mp4: 192x288 3 0s, 15.7ms
# video 1/1 (frame 304/3384) /content/Windmills.mp4: 192x288 2 0s, 20.4ms
# video 1/1 (frame 305/3384) /content/Windmills.mp4: 192x288 3 0s, 12.8ms
# video 1/1 (frame 306/3384) /content/Windmills.mp4: 192x288 2 0s, 11.1ms
# video 1/1 (frame 307/3384) /content/Windmills.mp4: 192x288 2 0s, 8.7ms
# video 1/1 (frame 308/3384) /content/Windmills.mp4: 192x288 2 0s, 9.0ms
# video 1/1 (frame 309/3384) /content/Windmills.mp4: 192x288 2 0s, 8.7ms
# video 1/1 (frame 310/3384) /content/Windmills.mp4: 192x288 2 0s, 9.9ms
# video 1/1 (frame 311/3384) /content/Windmills.mp4: 192x288 3 0s, 11.2ms
# video 1/1 (frame 312/3384) /content/Windmills.mp4: 192x288 3 0s, 8.5ms
# video 1/1 (frame 313/3384) /content/Windmills.mp4: 192x288 3 0s, 9.8ms
# video 1/1 (frame 314/3384) /content/Windmills.mp4: 192x288 2 0s, 10.1ms
# video 1/1 (frame 315/3384) /content/Windmills.mp4: 192x288 3 0s, 9.3ms
# video 1/1 (frame 316/3384) /content/Windmills.mp4: 192x288 5 0s, 9.0ms
# video 1/1 (frame 317/3384) /content/Windmills.mp4: 192x288 2 0s, 9.3ms
# video 1/1 (frame 318/3384) /content/Windmills.mp4: 192x288 2 0s, 9.1ms
# video 1/1 (frame 319/3384) /content/Windmills.mp4: 192x288 3 0s, 8.6ms
# video 1/1 (frame 320/3384) /content/Windmills.mp4: 192x288 4 0s, 12.1ms
# video 1/1 (frame 321/3384) /content/Windmills.mp4: 192x288 4 0s, 11.9ms
# video 1/1 (frame 322/3384) /content/Windmills.mp4: 192x288 5 0s, 8.7ms
# video 1/1 (frame 323/3384) /content/Windmills.mp4: 192x288 4 0s, 17.6ms
# video 1/1 (frame 324/3384) /content/Windmills.mp4: 192x288 5 0s, 10.5ms
# video 1/1 (frame 325/3384) /content/Windmills.mp4: 192x288 4 0s, 10.4ms
# video 1/1 (frame 326/3384) /content/Windmills.mp4: 192x288 4 0s, 8.5ms
# video 1/1 (frame 327/3384) /content/Windmills.mp4: 192x288 3 0s, 16.0ms
# video 1/1 (frame 328/3384) /content/Windmills.mp4: 192x288 3 0s, 8.8ms
# video 1/1 (frame 329/3384) /content/Windmills.mp4: 192x288 4 0s, 10.1ms
# video 1/1 (frame 330/3384) /content/Windmills.mp4: 192x288 2 0s, 8.7ms
# video 1/1 (frame 331/3384) /content/Windmills.mp4: 192x288 2 0s, 10.3ms
# video 1/1 (frame 332/3384) /content/Windmills.mp4: 192x288 1 0, 9.0ms
# video 1/1 (frame 333/3384) /content/Windmills.mp4: 192x288 1 0, 8.7ms
# video 1/1 (frame 334/3384) /content/Windmills.mp4: 192x288 2 0s, 12.3ms
# video 1/1 (frame 335/3384) /content/Windmills.mp4: 192x288 3 0s, 14.4ms
# video 1/1 (frame 336/3384) /content/Windmills.mp4: 192x288 3 0s, 9.7ms
# video 1/1 (frame 337/3384) /content/Windmills.mp4: 192x288 3 0s, 9.2ms
# video 1/1 (frame 338/3384) /content/Windmills.mp4: 192x288 3 0s, 9.5ms
# video 1/1 (frame 339/3384) /content/Windmills.mp4: 192x288 3 0s, 9.7ms
# video 1/1 (frame 340/3384) /content/Windmills.mp4: 192x288 3 0s, 9.5ms
# video 1/1 (frame 341/3384) /content/Windmills.mp4: 192x288 3 0s, 9.2ms
# video 1/1 (frame 342/3384) /content/Windmills.mp4: 192x288 4 0s, 16.6ms
# video 1/1 (frame 343/3384) /content/Windmills.mp4: 192x288 3 0s, 13.2ms
# video 1/1 (frame 344/3384) /content/Windmills.mp4: 192x288 3 0s, 22.3ms
# video 1/1 (frame 345/3384) /content/Windmills.mp4: 192x288 3 0s, 11.1ms
# video 1/1 (frame 346/3384) /content/Windmills.mp4: 192x288 3 0s, 17.3ms
# video 1/1 (frame 347/3384) /content/Windmills.mp4: 192x288 3 0s, 12.4ms
# video 1/1 (frame 348/3384) /content/Windmills.mp4: 192x288 4 0s, 9.1ms
# video 1/1 (frame 349/3384) /content/Windmills.mp4: 192x288 2 0s, 9.5ms
# video 1/1 (frame 350/3384) /content/Windmills.mp4: 192x288 3 0s, 9.0ms
# video 1/1 (frame 351/3384) /content/Windmills.mp4: 192x288 4 0s, 10.8ms
# video 1/1 (frame 352/3384) /content/Windmills.mp4: 192x288 3 0s, 11.3ms
# video 1/1 (frame 353/3384) /content/Windmills.mp4: 192x288 3 0s, 9.1ms
# video 1/1 (frame 354/3384) /content/Windmills.mp4: 192x288 2 0s, 14.7ms
# video 1/1 (frame 355/3384) /content/Windmills.mp4: 192x288 3 0s, 11.3ms
# video 1/1 (frame 356/3384) /content/Windmills.mp4: 192x288 3 0s, 12.0ms
# video 1/1 (frame 357/3384) /content/Windmills.mp4: 192x288 2 0s, 11.2ms
# video 1/1 (frame 358/3384) /content/Windmills.mp4: 192x288 2 0s, 12.0ms
# video 1/1 (frame 359/3384) /content/Windmills.mp4: 192x288 2 0s, 10.1ms
# video 1/1 (frame 360/3384) /content/Windmills.mp4: 192x288 3 0s, 8.3ms
# video 1/1 (frame 361/3384) /content/Windmills.mp4: 192x288 2 0s, 9.5ms
# video 1/1 (frame 362/3384) /content/Windmills.mp4: 192x288 3 0s, 11.4ms
# video 1/1 (frame 363/3384) /content/Windmills.mp4: 192x288 2 0s, 12.5ms
# video 1/1 (frame 364/3384) /content/Windmills.mp4: 192x288 2 0s, 20.1ms
# video 1/1 (frame 365/3384) /content/Windmills.mp4: 192x288 3 0s, 13.6ms
# video 1/1 (frame 366/3384) /content/Windmills.mp4: 192x288 2 0s, 15.8ms
# video 1/1 (frame 367/3384) /content/Windmills.mp4: 192x288 2 0s, 17.1ms
# video 1/1 (frame 368/3384) /content/Windmills.mp4: 192x288 2 0s, 9.3ms
# video 1/1 (frame 369/3384) /content/Windmills.mp4: 192x288 3 0s, 9.9ms
# video 1/1 (frame 370/3384) /content/Windmills.mp4: 192x288 4 0s, 12.6ms
# video 1/1 (frame 371/3384) /content/Windmills.mp4: 192x288 4 0s, 18.4ms
# video 1/1 (frame 372/3384) /content/Windmills.mp4: 192x288 4 0s, 9.7ms
# video 1/1 (frame 373/3384) /content/Windmills.mp4: 192x288 5 0s, 8.7ms
# video 1/1 (frame 374/3384) /content/Windmills.mp4: 192x288 5 0s, 9.8ms
# video 1/1 (frame 375/3384) /content/Windmills.mp4: 192x288 6 0s, 9.8ms
# video 1/1 (frame 376/3384) /content/Windmills.mp4: 192x288 4 0s, 9.2ms
# video 1/1 (frame 377/3384) /content/Windmills.mp4: 192x288 4 0s, 9.2ms
# video 1/1 (frame 378/3384) /content/Windmills.mp4: 192x288 3 0s, 12.4ms
# video 1/1 (frame 379/3384) /content/Windmills.mp4: 192x288 2 0s, 9.0ms
# video 1/1 (frame 380/3384) /content/Windmills.mp4: 192x288 3 0s, 10.8ms
# video 1/1 (frame 381/3384) /content/Windmills.mp4: 192x288 2 0s, 9.3ms
# video 1/1 (frame 382/3384) /content/Windmills.mp4: 192x288 2 0s, 22.5ms
# video 1/1 (frame 383/3384) /content/Windmills.mp4: 192x288 3 0s, 9.4ms
# video 1/1 (frame 384/3384) /content/Windmills.mp4: 192x288 4 0s, 14.3ms
# video 1/1 (frame 385/3384) /content/Windmills.mp4: 192x288 2 0s, 8.7ms
# video 1/1 (frame 386/3384) /content/Windmills.mp4: 192x288 2 0s, 17.2ms
# video 1/1 (frame 387/3384) /content/Windmills.mp4: 192x288 3 0s, 11.7ms
# video 1/1 (frame 388/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 389/3384) /content/Windmills.mp4: 192x288 4 0s, 9.5ms
# video 1/1 (frame 390/3384) /content/Windmills.mp4: 192x288 4 0s, 13.2ms
# video 1/1 (frame 391/3384) /content/Windmills.mp4: 192x288 3 0s, 10.5ms
# video 1/1 (frame 392/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 393/3384) /content/Windmills.mp4: 192x288 3 0s, 8.7ms
# video 1/1 (frame 394/3384) /content/Windmills.mp4: 192x288 3 0s, 9.7ms
# video 1/1 (frame 395/3384) /content/Windmills.mp4: 192x288 4 0s, 9.5ms
# video 1/1 (frame 396/3384) /content/Windmills.mp4: 192x288 4 0s, 12.2ms
# video 1/1 (frame 397/3384) /content/Windmills.mp4: 192x288 4 0s, 10.8ms
# video 1/1 (frame 398/3384) /content/Windmills.mp4: 192x288 4 0s, 9.0ms
# video 1/1 (frame 399/3384) /content/Windmills.mp4: 192x288 4 0s, 9.0ms
# video 1/1 (frame 400/3384) /content/Windmills.mp4: 192x288 3 0s, 9.1ms
# video 1/1 (frame 401/3384) /content/Windmills.mp4: 192x288 3 0s, 13.0ms
# video 1/1 (frame 402/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 403/3384) /content/Windmills.mp4: 192x288 2 0s, 22.0ms
# video 1/1 (frame 404/3384) /content/Windmills.mp4: 192x288 2 0s, 10.3ms
# video 1/1 (frame 405/3384) /content/Windmills.mp4: 192x288 2 0s, 10.8ms
# video 1/1 (frame 406/3384) /content/Windmills.mp4: 192x288 2 0s, 8.9ms
# video 1/1 (frame 407/3384) /content/Windmills.mp4: 192x288 2 0s, 10.3ms
# video 1/1 (frame 408/3384) /content/Windmills.mp4: 192x288 2 0s, 9.1ms
# video 1/1 (frame 409/3384) /content/Windmills.mp4: 192x288 2 0s, 8.9ms
# video 1/1 (frame 410/3384) /content/Windmills.mp4: 192x288 2 0s, 12.5ms
# video 1/1 (frame 411/3384) /content/Windmills.mp4: 192x288 2 0s, 10.4ms
# video 1/1 (frame 412/3384) /content/Windmills.mp4: 192x288 2 0s, 10.6ms
# video 1/1 (frame 413/3384) /content/Windmills.mp4: 192x288 2 0s, 10.8ms
# video 1/1 (frame 414/3384) /content/Windmills.mp4: 192x288 2 0s, 16.6ms
# video 1/1 (frame 415/3384) /content/Windmills.mp4: 192x288 2 0s, 10.2ms
# video 1/1 (frame 416/3384) /content/Windmills.mp4: 192x288 2 0s, 10.6ms
# video 1/1 (frame 417/3384) /content/Windmills.mp4: 192x288 2 0s, 8.6ms
# video 1/1 (frame 418/3384) /content/Windmills.mp4: 192x288 2 0s, 8.7ms
# video 1/1 (frame 419/3384) /content/Windmills.mp4: 192x288 2 0s, 12.9ms
# video 1/1 (frame 420/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 421/3384) /content/Windmills.mp4: 192x288 2 0s, 9.4ms
# video 1/1 (frame 422/3384) /content/Windmills.mp4: 192x288 2 0s, 8.9ms
# video 1/1 (frame 423/3384) /content/Windmills.mp4: 192x288 3 0s, 18.7ms
# video 1/1 (frame 424/3384) /content/Windmills.mp4: 192x288 4 0s, 8.8ms
# video 1/1 (frame 425/3384) /content/Windmills.mp4: 192x288 4 0s, 10.0ms
# video 1/1 (frame 426/3384) /content/Windmills.mp4: 192x288 4 0s, 11.7ms
# video 1/1 (frame 427/3384) /content/Windmills.mp4: 192x288 2 0s, 11.6ms
# video 1/1 (frame 428/3384) /content/Windmills.mp4: 192x288 3 0s, 23.7ms
# video 1/1 (frame 429/3384) /content/Windmills.mp4: 192x288 3 0s, 12.9ms
# video 1/1 (frame 430/3384) /content/Windmills.mp4: 192x288 3 0s, 17.4ms
# video 1/1 (frame 431/3384) /content/Windmills.mp4: 192x288 4 0s, 9.1ms
# video 1/1 (frame 432/3384) /content/Windmills.mp4: 192x288 5 0s, 9.3ms
# video 1/1 (frame 433/3384) /content/Windmills.mp4: 192x288 5 0s, 8.9ms
# video 1/1 (frame 434/3384) /content/Windmills.mp4: 192x288 5 0s, 9.0ms
# video 1/1 (frame 435/3384) /content/Windmills.mp4: 192x288 4 0s, 9.0ms
# video 1/1 (frame 436/3384) /content/Windmills.mp4: 192x288 4 0s, 14.6ms
# video 1/1 (frame 437/3384) /content/Windmills.mp4: 192x288 4 0s, 8.8ms
# video 1/1 (frame 438/3384) /content/Windmills.mp4: 192x288 4 0s, 8.7ms
# video 1/1 (frame 439/3384) /content/Windmills.mp4: 192x288 4 0s, 11.6ms
# video 1/1 (frame 440/3384) /content/Windmills.mp4: 192x288 4 0s, 8.7ms
# video 1/1 (frame 441/3384) /content/Windmills.mp4: 192x288 3 0s, 9.0ms
# video 1/1 (frame 442/3384) /content/Windmills.mp4: 192x288 3 0s, 11.2ms
# video 1/1 (frame 443/3384) /content/Windmills.mp4: 192x288 3 0s, 8.4ms
# video 1/1 (frame 444/3384) /content/Windmills.mp4: 192x288 3 0s, 15.1ms
# video 1/1 (frame 445/3384) /content/Windmills.mp4: 192x288 3 0s, 8.7ms
# video 1/1 (frame 446/3384) /content/Windmills.mp4: 192x288 2 0s, 11.2ms
# video 1/1 (frame 447/3384) /content/Windmills.mp4: 192x288 4 0s, 9.1ms
# video 1/1 (frame 448/3384) /content/Windmills.mp4: 192x288 2 0s, 9.1ms
# video 1/1 (frame 449/3384) /content/Windmills.mp4: 192x288 2 0s, 21.0ms
# video 1/1 (frame 450/3384) /content/Windmills.mp4: 192x288 2 0s, 9.3ms
# video 1/1 (frame 451/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 452/3384) /content/Windmills.mp4: 192x288 2 0s, 12.9ms
# video 1/1 (frame 453/3384) /content/Windmills.mp4: 192x288 3 0s, 8.3ms
# video 1/1 (frame 454/3384) /content/Windmills.mp4: 192x288 2 0s, 8.7ms
# video 1/1 (frame 455/3384) /content/Windmills.mp4: 192x288 2 0s, 10.4ms
# video 1/1 (frame 456/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 457/3384) /content/Windmills.mp4: 192x288 2 0s, 9.4ms
# video 1/1 (frame 458/3384) /content/Windmills.mp4: 192x288 2 0s, 9.5ms
# video 1/1 (frame 459/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 460/3384) /content/Windmills.mp4: 192x288 2 0s, 11.8ms
# video 1/1 (frame 461/3384) /content/Windmills.mp4: 192x288 2 0s, 14.6ms
# video 1/1 (frame 462/3384) /content/Windmills.mp4: 192x288 3 0s, 12.4ms
# video 1/1 (frame 463/3384) /content/Windmills.mp4: 192x288 2 0s, 11.6ms
# video 1/1 (frame 464/3384) /content/Windmills.mp4: 192x288 3 0s, 10.8ms
# video 1/1 (frame 465/3384) /content/Windmills.mp4: 192x288 2 0s, 15.0ms
# video 1/1 (frame 466/3384) /content/Windmills.mp4: 192x288 2 0s, 10.0ms
# video 1/1 (frame 467/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 468/3384) /content/Windmills.mp4: 192x288 2 0s, 13.8ms
# video 1/1 (frame 469/3384) /content/Windmills.mp4: 192x288 2 0s, 9.1ms
# video 1/1 (frame 470/3384) /content/Windmills.mp4: 192x288 1 0, 9.6ms
# video 1/1 (frame 471/3384) /content/Windmills.mp4: 192x288 2 0s, 17.9ms
# video 1/1 (frame 472/3384) /content/Windmills.mp4: 192x288 3 0s, 9.2ms
# video 1/1 (frame 473/3384) /content/Windmills.mp4: 192x288 4 0s, 11.7ms
# video 1/1 (frame 474/3384) /content/Windmills.mp4: 192x288 3 0s, 9.0ms
# video 1/1 (frame 475/3384) /content/Windmills.mp4: 192x288 3 0s, 9.4ms
# video 1/1 (frame 476/3384) /content/Windmills.mp4: 192x288 4 0s, 8.9ms
# video 1/1 (frame 477/3384) /content/Windmills.mp4: 192x288 3 0s, 9.0ms
# video 1/1 (frame 478/3384) /content/Windmills.mp4: 192x288 3 0s, 9.2ms
# video 1/1 (frame 479/3384) /content/Windmills.mp4: 192x288 3 0s, 13.9ms
# video 1/1 (frame 480/3384) /content/Windmills.mp4: 192x288 3 0s, 13.9ms
# video 1/1 (frame 481/3384) /content/Windmills.mp4: 192x288 3 0s, 17.6ms
# video 1/1 (frame 482/3384) /content/Windmills.mp4: 192x288 3 0s, 11.3ms
# video 1/1 (frame 483/3384) /content/Windmills.mp4: 192x288 3 0s, 11.6ms
# video 1/1 (frame 484/3384) /content/Windmills.mp4: 192x288 2 0s, 18.0ms
# video 1/1 (frame 485/3384) /content/Windmills.mp4: 192x288 2 0s, 20.3ms
# video 1/1 (frame 486/3384) /content/Windmills.mp4: 192x288 2 0s, 12.4ms
# video 1/1 (frame 487/3384) /content/Windmills.mp4: 192x288 2 0s, 12.2ms
# video 1/1 (frame 488/3384) /content/Windmills.mp4: 192x288 2 0s, 22.1ms
# video 1/1 (frame 489/3384) /content/Windmills.mp4: 192x288 2 0s, 22.5ms
# video 1/1 (frame 490/3384) /content/Windmills.mp4: 192x288 2 0s, 21.3ms
# video 1/1 (frame 491/3384) /content/Windmills.mp4: 192x288 2 0s, 14.8ms
# video 1/1 (frame 492/3384) /content/Windmills.mp4: 192x288 2 0s, 16.4ms
# video 1/1 (frame 493/3384) /content/Windmills.mp4: 192x288 2 0s, 15.2ms
# video 1/1 (frame 494/3384) /content/Windmills.mp4: 192x288 3 0s, 12.4ms
# video 1/1 (frame 495/3384) /content/Windmills.mp4: 192x288 3 0s, 12.2ms
# video 1/1 (frame 496/3384) /content/Windmills.mp4: 192x288 2 0s, 15.1ms
# video 1/1 (frame 497/3384) /content/Windmills.mp4: 192x288 2 0s, 16.9ms
# video 1/1 (frame 498/3384) /content/Windmills.mp4: 192x288 2 0s, 16.4ms
# video 1/1 (frame 499/3384) /content/Windmills.mp4: 192x288 2 0s, 16.1ms
# video 1/1 (frame 500/3384) /content/Windmills.mp4: 192x288 3 0s, 15.9ms
# video 1/1 (frame 501/3384) /content/Windmills.mp4: 192x288 3 0s, 15.4ms
# video 1/1 (frame 502/3384) /content/Windmills.mp4: 192x288 3 0s, 15.2ms
# video 1/1 (frame 503/3384) /content/Windmills.mp4: 192x288 3 0s, 16.8ms
# video 1/1 (frame 504/3384) /content/Windmills.mp4: 192x288 3 0s, 13.6ms
# video 1/1 (frame 505/3384) /content/Windmills.mp4: 192x288 2 0s, 13.0ms
# video 1/1 (frame 506/3384) /content/Windmills.mp4: 192x288 2 0s, 10.9ms
# video 1/1 (frame 507/3384) /content/Windmills.mp4: 192x288 2 0s, 12.4ms
# video 1/1 (frame 508/3384) /content/Windmills.mp4: 192x288 2 0s, 11.0ms
# video 1/1 (frame 509/3384) /content/Windmills.mp4: 192x288 2 0s, 19.2ms
# video 1/1 (frame 510/3384) /content/Windmills.mp4: 192x288 4 0s, 13.0ms
# video 1/1 (frame 511/3384) /content/Windmills.mp4: 192x288 3 0s, 14.3ms
# video 1/1 (frame 512/3384) /content/Windmills.mp4: 192x288 3 0s, 19.9ms
# video 1/1 (frame 513/3384) /content/Windmills.mp4: 192x288 3 0s, 15.0ms
# video 1/1 (frame 514/3384) /content/Windmills.mp4: 192x288 3 0s, 13.5ms
# video 1/1 (frame 515/3384) /content/Windmills.mp4: 192x288 3 0s, 14.8ms
# video 1/1 (frame 516/3384) /content/Windmills.mp4: 192x288 3 0s, 14.1ms
# video 1/1 (frame 517/3384) /content/Windmills.mp4: 192x288 3 0s, 23.5ms
# video 1/1 (frame 518/3384) /content/Windmills.mp4: 192x288 2 0s, 29.7ms
# video 1/1 (frame 519/3384) /content/Windmills.mp4: 192x288 2 0s, 15.0ms
# video 1/1 (frame 520/3384) /content/Windmills.mp4: 192x288 4 0s, 20.9ms
# video 1/1 (frame 521/3384) /content/Windmills.mp4: 192x288 4 0s, 13.9ms
# video 1/1 (frame 522/3384) /content/Windmills.mp4: 192x288 4 0s, 13.0ms
# video 1/1 (frame 523/3384) /content/Windmills.mp4: 192x288 4 0s, 14.6ms
# video 1/1 (frame 524/3384) /content/Windmills.mp4: 192x288 4 0s, 11.7ms
# video 1/1 (frame 525/3384) /content/Windmills.mp4: 192x288 3 0s, 13.6ms
# video 1/1 (frame 526/3384) /content/Windmills.mp4: 192x288 2 0s, 12.4ms
# video 1/1 (frame 527/3384) /content/Windmills.mp4: 192x288 2 0s, 16.8ms
# video 1/1 (frame 528/3384) /content/Windmills.mp4: 192x288 2 0s, 16.6ms
# video 1/1 (frame 529/3384) /content/Windmills.mp4: 192x288 2 0s, 17.3ms
# video 1/1 (frame 530/3384) /content/Windmills.mp4: 192x288 2 0s, 16.6ms
# video 1/1 (frame 531/3384) /content/Windmills.mp4: 192x288 2 0s, 10.9ms
# video 1/1 (frame 532/3384) /content/Windmills.mp4: 192x288 4 0s, 15.5ms
# video 1/1 (frame 533/3384) /content/Windmills.mp4: 192x288 3 0s, 19.9ms
# video 1/1 (frame 534/3384) /content/Windmills.mp4: 192x288 3 0s, 20.8ms
# video 1/1 (frame 535/3384) /content/Windmills.mp4: 192x288 4 0s, 19.9ms
# video 1/1 (frame 536/3384) /content/Windmills.mp4: 192x288 4 0s, 13.6ms
# video 1/1 (frame 537/3384) /content/Windmills.mp4: 192x288 3 0s, 13.2ms
# video 1/1 (frame 538/3384) /content/Windmills.mp4: 192x288 5 0s, 12.5ms
# video 1/1 (frame 539/3384) /content/Windmills.mp4: 192x288 5 0s, 16.2ms
# video 1/1 (frame 540/3384) /content/Windmills.mp4: 192x288 4 0s, 16.9ms
# video 1/1 (frame 541/3384) /content/Windmills.mp4: 192x288 3 0s, 14.0ms
# video 1/1 (frame 542/3384) /content/Windmills.mp4: 192x288 3 0s, 19.7ms
# video 1/1 (frame 543/3384) /content/Windmills.mp4: 192x288 3 0s, 14.1ms
# video 1/1 (frame 544/3384) /content/Windmills.mp4: 192x288 3 0s, 23.3ms
# video 1/1 (frame 545/3384) /content/Windmills.mp4: 192x288 5 0s, 15.8ms
# video 1/1 (frame 546/3384) /content/Windmills.mp4: 192x288 4 0s, 13.4ms
# video 1/1 (frame 547/3384) /content/Windmills.mp4: 192x288 4 0s, 15.3ms
# video 1/1 (frame 548/3384) /content/Windmills.mp4: 192x288 3 0s, 11.5ms
# video 1/1 (frame 549/3384) /content/Windmills.mp4: 192x288 3 0s, 19.9ms
# video 1/1 (frame 550/3384) /content/Windmills.mp4: 192x288 3 0s, 12.7ms
# video 1/1 (frame 551/3384) /content/Windmills.mp4: 192x288 2 0s, 17.9ms
# video 1/1 (frame 552/3384) /content/Windmills.mp4: 192x288 3 0s, 13.4ms
# video 1/1 (frame 553/3384) /content/Windmills.mp4: 192x288 3 0s, 15.3ms
# video 1/1 (frame 554/3384) /content/Windmills.mp4: 192x288 4 0s, 14.0ms
# video 1/1 (frame 555/3384) /content/Windmills.mp4: 192x288 3 0s, 21.9ms
# video 1/1 (frame 556/3384) /content/Windmills.mp4: 192x288 4 0s, 19.6ms
# video 1/1 (frame 557/3384) /content/Windmills.mp4: 192x288 4 0s, 22.7ms
# video 1/1 (frame 558/3384) /content/Windmills.mp4: 192x288 3 0s, 23.5ms
# video 1/1 (frame 559/3384) /content/Windmills.mp4: 192x288 4 0s, 16.2ms
# video 1/1 (frame 560/3384) /content/Windmills.mp4: 192x288 3 0s, 17.8ms
# video 1/1 (frame 561/3384) /content/Windmills.mp4: 192x288 4 0s, 15.9ms
# video 1/1 (frame 562/3384) /content/Windmills.mp4: 192x288 3 0s, 15.7ms
# video 1/1 (frame 563/3384) /content/Windmills.mp4: 192x288 3 0s, 14.8ms
# video 1/1 (frame 564/3384) /content/Windmills.mp4: 192x288 3 0s, 16.0ms
# video 1/1 (frame 565/3384) /content/Windmills.mp4: 192x288 3 0s, 14.6ms
# video 1/1 (frame 566/3384) /content/Windmills.mp4: 192x288 3 0s, 18.8ms
# video 1/1 (frame 567/3384) /content/Windmills.mp4: 192x288 3 0s, 12.5ms
# video 1/1 (frame 568/3384) /content/Windmills.mp4: 192x288 2 0s, 19.1ms
# video 1/1 (frame 569/3384) /content/Windmills.mp4: 192x288 2 0s, 10.8ms
# video 1/1 (frame 570/3384) /content/Windmills.mp4: 192x288 2 0s, 10.1ms
# video 1/1 (frame 571/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 572/3384) /content/Windmills.mp4: 192x288 2 0s, 21.6ms
# video 1/1 (frame 573/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 574/3384) /content/Windmills.mp4: 192x288 2 0s, 12.4ms
# video 1/1 (frame 575/3384) /content/Windmills.mp4: 192x288 2 0s, 8.9ms
# video 1/1 (frame 576/3384) /content/Windmills.mp4: 192x288 2 0s, 9.4ms
# video 1/1 (frame 577/3384) /content/Windmills.mp4: 192x288 2 0s, 10.2ms
# video 1/1 (frame 578/3384) /content/Windmills.mp4: 192x288 2 0s, 9.9ms
# video 1/1 (frame 579/3384) /content/Windmills.mp4: 192x288 2 0s, 9.3ms
# video 1/1 (frame 580/3384) /content/Windmills.mp4: 192x288 2 0s, 10.4ms
# video 1/1 (frame 581/3384) /content/Windmills.mp4: 192x288 2 0s, 10.7ms
# video 1/1 (frame 582/3384) /content/Windmills.mp4: 192x288 2 0s, 8.7ms
# video 1/1 (frame 583/3384) /content/Windmills.mp4: 192x288 2 0s, 10.8ms
# video 1/1 (frame 584/3384) /content/Windmills.mp4: 192x288 2 0s, 17.1ms
# video 1/1 (frame 585/3384) /content/Windmills.mp4: 192x288 2 0s, 12.2ms
# video 1/1 (frame 586/3384) /content/Windmills.mp4: 192x288 2 0s, 9.6ms
# video 1/1 (frame 587/3384) /content/Windmills.mp4: 192x288 2 0s, 8.6ms
# video 1/1 (frame 588/3384) /content/Windmills.mp4: 192x288 2 0s, 8.7ms
# video 1/1 (frame 589/3384) /content/Windmills.mp4: 192x288 2 0s, 13.8ms
# video 1/1 (frame 590/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 591/3384) /content/Windmills.mp4: 192x288 2 0s, 10.6ms
# video 1/1 (frame 592/3384) /content/Windmills.mp4: 192x288 2 0s, 12.4ms
# video 1/1 (frame 593/3384) /content/Windmills.mp4: 192x288 2 0s, 8.6ms
# video 1/1 (frame 594/3384) /content/Windmills.mp4: 192x288 3 0s, 13.3ms
# video 1/1 (frame 595/3384) /content/Windmills.mp4: 192x288 3 0s, 11.9ms
# video 1/1 (frame 596/3384) /content/Windmills.mp4: 192x288 2 0s, 10.7ms
# video 1/1 (frame 597/3384) /content/Windmills.mp4: 192x288 2 0s, 9.3ms
# video 1/1 (frame 598/3384) /content/Windmills.mp4: 192x288 3 0s, 9.4ms
# video 1/1 (frame 599/3384) /content/Windmills.mp4: 192x288 2 0s, 10.0ms
# video 1/1 (frame 600/3384) /content/Windmills.mp4: 192x288 2 0s, 8.5ms
# video 1/1 (frame 601/3384) /content/Windmills.mp4: 192x288 2 0s, 8.6ms
# video 1/1 (frame 602/3384) /content/Windmills.mp4: 192x288 2 0s, 17.1ms
# video 1/1 (frame 603/3384) /content/Windmills.mp4: 192x288 2 0s, 12.4ms
# video 1/1 (frame 604/3384) /content/Windmills.mp4: 192x288 2 0s, 13.2ms
# video 1/1 (frame 605/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 606/3384) /content/Windmills.mp4: 192x288 2 0s, 9.2ms
# video 1/1 (frame 607/3384) /content/Windmills.mp4: 192x288 3 0s, 8.6ms
# video 1/1 (frame 608/3384) /content/Windmills.mp4: 192x288 2 0s, 9.4ms
# video 1/1 (frame 609/3384) /content/Windmills.mp4: 192x288 2 0s, 8.8ms
# video 1/1 (frame 610/3384) /content/Windmills.mp4: 192x288 2 0s, 11.6ms
# video 1/1 (frame 611/3384) /content/Windmills.mp4: 192x288 2 0s, 12.2ms
# video 1/1 (frame 612/3384) /content/Windmills.mp4: 192x288 2 0s, 10.8ms
# video 1/1 (frame 613/3384) /content/Windmills.mp4: 192x288 2 0s, 14.3ms
# video 1/1 (frame 614/3384) /content/Windmills.mp4: 192x288 2 0s, 12.6ms
# video 1/1 (frame 615/3384) /content/Windmills.mp4: 192x288 3 0s, 16.3ms
# video 1/1 (frame 616/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 617/3384) /content/Windmills.mp4: 192x288 3 0s, 13.3ms
# video 1/1 (frame 618/3384) /content/Windmills.mp4: 192x288 3 0s, 13.5ms
# video 1/1 (frame 619/3384) /content/Windmills.mp4: 192x288 3 0s, 10.2ms
# video 1/1 (frame 620/3384) /content/Windmills.mp4: 192x288 2 0s, 12.2ms
# video 1/1 (frame 621/3384) /content/Windmills.mp4: 192x288 4 0s, 12.1ms
# video 1/1 (frame 622/3384) /content/Windmills.mp4: 192x288 4 0s, 16.9ms
# video 1/1 (frame 623/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 624/3384) /content/Windmills.mp4: 192x288 4 0s, 10.2ms
# video 1/1 (frame 625/3384) /content/Windmills.mp4: 192x288 4 0s, 8.8ms
# video 1/1 (frame 626/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 627/3384) /content/Windmills.mp4: 192x288 3 0s, 8.6ms
# video 1/1 (frame 628/3384) /content/Windmills.mp4: 192x288 3 0s, 9.0ms
# video 1/1 (frame 629/3384) /content/Windmills.mp4: 192x288 3 0s, 8.8ms
# video 1/1 (frame 630/3384) /content/Windmills.mp4: 192x288 3 0s, 10.7ms
# video 1/1 (frame 631/3384) /content/Windmills.mp4: 192x288 3 0s, 11.9ms
# video 1/1 (frame 632/3384) /content/Windmills.mp4: 192x288 3 0s, 11.6ms
# video 1/1 (frame 633/3384) /content/Windmills.mp4: 192x288 4 0s, 9.7ms
# video 1/1 (frame 634/3384) /content/Windmills.mp4: 192x288 3 0s, 16.5ms
# video 1/1 (frame 635/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 636/3384) /content/Windmills.mp4: 192x288 3 0s, 14.7ms
# video 1/1 (frame 637/3384) /content/Windmills.mp4: 192x288 3 0s, 14.3ms
# video 1/1 (frame 638/3384) /content/Windmills.mp4: 192x288 3 0s, 10.2ms
# video 1/1 (frame 639/3384) /content/Windmills.mp4: 192x288 3 0s, 9.0ms
# video 1/1 (frame 640/3384) /content/Windmills.mp4: 192x288 4 0s, 10.0ms
# video 1/1 (frame 641/3384) /content/Windmills.mp4: 192x288 4 0s, 12.5ms
# video 1/1 (frame 642/3384) /content/Windmills.mp4: 192x288 6 0s, 12.6ms
# video 1/1 (frame 643/3384) /content/Windmills.mp4: 192x288 5 0s, 10.8ms
# video 1/1 (frame 644/3384) /content/Windmills.mp4: 192x288 4 0s, 9.8ms
# video 1/1 (frame 645/3384) /content/Windmills.mp4: 192x288 4 0s, 8.7ms
# video 1/1 (frame 646/3384) /content/Windmills.mp4: 192x288 4 0s, 8.8ms
# video 1/1 (frame 647/3384) /content/Windmills.mp4: 192x288 3 0s, 8.7ms
# video 1/1 (frame 648/3384) /content/Windmills.mp4: 192x288 3 0s, 9.2ms
# video 1/1 (frame 649/3384) /content/Windmills.mp4: 192x288 3 0s, 12.0ms
# video 1/1 (frame 650/3384) /content/Windmills.mp4: 192x288 3 0s, 16.2ms
# video 1/1 (frame 651/3384) /content/Windmills.mp4: 192x288 3 0s, 20.4ms
# video 1/1 (frame 652/3384) /content/Windmills.mp4: 192x288 3 0s, 11.0ms
# video 1/1 (frame 653/3384) /content/Windmills.mp4: 192x288 3 0s, 11.7ms
# video 1/1 (frame 654/3384) /content/Windmills.mp4: 192x288 3 0s, 12.5ms
# video 1/1 (frame 655/3384) /content/Windmills.mp4: 192x288 3 0s, 12.5ms
# video 1/1 (frame 656/3384) /content/Windmills.mp4: 192x288 3 0s, 10.9ms
# video 1/1 (frame 657/3384) /content/Windmills.mp4: 192x288 3 0s, 10.3ms
# video 1/1 (frame 658/3384) /content/Windmills.mp4: 192x288 3 0s, 10.5ms
# video 1/1 (frame 659/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 660/3384) /content/Windmills.mp4: 192x288 3 0s, 9.7ms
# video 1/1 (frame 661/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 662/3384) /content/Windmills.mp4: 192x288 3 0s, 12.0ms
# video 1/1 (frame 663/3384) /content/Windmills.mp4: 192x288 3 0s, 9.8ms
# video 1/1 (frame 664/3384) /content/Windmills.mp4: 192x288 3 0s, 9.3ms
# video 1/1 (frame 665/3384) /content/Windmills.mp4: 192x288 3 0s, 8.5ms
# video 1/1 (frame 666/3384) /content/Windmills.mp4: 192x288 4 0s, 8.7ms
# video 1/1 (frame 667/3384) /content/Windmills.mp4: 192x288 3 0s, 9.7ms
# video 1/1 (frame 668/3384) /content/Windmills.mp4: 192x288 3 0s, 9.2ms
# video 1/1 (frame 669/3384) /content/Windmills.mp4: 192x288 3 0s, 11.8ms
# ...
# video 1/1 (frame 3174/3384) /content/Windmills.mp4: 192x288 3 0s, 9.7ms
# video 1/1 (frame 3175/3384) /content/Windmills.mp4: 192x288 4 0s, 9.3ms
# video 1/1 (frame 3176/3384) /content/Windmills.mp4: 192x288 3 0s, 9.8ms
# video 1/1 (frame 3177/3384) /content/Windmills.mp4: 192x288 2 0s, 8.2ms
# video 1/1 (frame 3178/3384) /content/Windmills.mp4: 192x288 2 0s, 9.5ms
# video 1/1 (frame 3179/3384) /content/Windmills.mp4: 192x288 2 0s, 10.3ms
# video 1/1 (frame 3180/3384) /content/Windmills.mp4: 192x288 1 0, 10.4ms
# video 1/1 (frame 3181/3384) /content/Windmills.mp4: 192x288 3 0s, 9.7ms
# video 1/1 (frame 3182/3384) /content/Windmills.mp4: 192x288 4 0s, 8.3ms
# video 1/1 (frame 3183/3384) /content/Windmills.mp4: 192x288 3 0s, 10.3ms
# video 1/1 (frame 3184/3384) /content/Windmills.mp4: 192x288 4 0s, 10.2ms
# video 1/1 (frame 3185/3384) /content/Windmills.mp4: 192x288 4 0s, 10.2ms
# video 1/1 (frame 3186/3384) /content/Windmills.mp4: 192x288 4 0s, 9.9ms
# video 1/1 (frame 3187/3384) /content/Windmills.mp4: 192x288 3 0s, 13.9ms
# video 1/1 (frame 3188/3384) /content/Windmills.mp4: 192x288 4 0s, 8.4ms
# video 1/1 (frame 3189/3384) /content/Windmills.mp4: 192x288 4 0s, 10.6ms
# video 1/1 (frame 3190/3384) /content/Windmills.mp4: 192x288 4 0s, 9.3ms
# video 1/1 (frame 3191/3384) /content/Windmills.mp4: 192x288 5 0s, 10.9ms
# video 1/1 (frame 3192/3384) /content/Windmills.mp4: 192x288 5 0s, 8.2ms
# video 1/1 (frame 3193/3384) /content/Windmills.mp4: 192x288 5 0s, 9.1ms
# video 1/1 (frame 3194/3384) /content/Windmills.mp4: 192x288 5 0s, 9.5ms
# video 1/1 (frame 3195/3384) /content/Windmills.mp4: 192x288 8 0s, 9.4ms
# video 1/1 (frame 3196/3384) /content/Windmills.mp4: 192x288 4 0s, 10.5ms
# video 1/1 (frame 3197/3384) /content/Windmills.mp4: 192x288 6 0s, 8.1ms
# video 1/1 (frame 3198/3384) /content/Windmills.mp4: 192x288 9 0s, 9.6ms
# video 1/1 (frame 3199/3384) /content/Windmills.mp4: 192x288 9 0s, 10.1ms
# video 1/1 (frame 3200/3384) /content/Windmills.mp4: 192x288 5 0s, 10.3ms
# video 1/1 (frame 3201/3384) /content/Windmills.mp4: 192x288 4 0s, 10.0ms
# video 1/1 (frame 3202/3384) /content/Windmills.mp4: 192x288 6 0s, 8.3ms
# video 1/1 (frame 3203/3384) /content/Windmills.mp4: 192x288 5 0s, 9.7ms
# video 1/1 (frame 3204/3384) /content/Windmills.mp4: 192x288 5 0s, 16.8ms
# video 1/1 (frame 3205/3384) /content/Windmills.mp4: 192x288 5 0s, 10.2ms
# video 1/1 (frame 3206/3384) /content/Windmills.mp4: 192x288 3 0s, 13.1ms
# video 1/1 (frame 3207/3384) /content/Windmills.mp4: 192x288 3 0s, 9.0ms
# video 1/1 (frame 3208/3384) /content/Windmills.mp4: 192x288 3 0s, 9.5ms
# video 1/1 (frame 3209/3384) /content/Windmills.mp4: 192x288 3 0s, 12.7ms
# video 1/1 (frame 3210/3384) /content/Windmills.mp4: 192x288 1 0, 9.4ms
# video 1/1 (frame 3211/3384) /content/Windmills.mp4: 192x288 4 0s, 10.9ms
# video 1/1 (frame 3212/3384) /content/Windmills.mp4: 192x288 5 0s, 10.0ms
# video 1/1 (frame 3213/3384) /content/Windmills.mp4: 192x288 5 0s, 8.7ms
# video 1/1 (frame 3214/3384) /content/Windmills.mp4: 192x288 5 0s, 9.6ms
# video 1/1 (frame 3215/3384) /content/Windmills.mp4: 192x288 3 0s, 9.4ms
# video 1/1 (frame 3216/3384) /content/Windmills.mp4: 192x288 4 0s, 10.0ms
# video 1/1 (frame 3217/3384) /content/Windmills.mp4: 192x288 3 0s, 10.9ms
# video 1/1 (frame 3218/3384) /content/Windmills.mp4: 192x288 4 0s, 9.3ms
# video 1/1 (frame 3219/3384) /content/Windmills.mp4: 192x288 4 0s, 10.0ms
# video 1/1 (frame 3220/3384) /content/Windmills.mp4: 192x288 5 0s, 13.8ms
# video 1/1 (frame 3221/3384) /content/Windmills.mp4: 192x288 2 0s, 10.2ms
# video 1/1 (frame 3222/3384) /content/Windmills.mp4: 192x288 2 0s, 9.8ms
# video 1/1 (frame 3223/3384) /content/Windmills.mp4: 192x288 1 0, 8.7ms
# video 1/1 (frame 3224/3384) /content/Windmills.mp4: 192x288 1 0, 9.3ms
# video 1/1 (frame 3225/3384) /content/Windmills.mp4: 192x288 4 0s, 9.7ms
# video 1/1 (frame 3226/3384) /content/Windmills.mp4: 192x288 3 0s, 10.0ms
# video 1/1 (frame 3227/3384) /content/Windmills.mp4: 192x288 8 0s, 8.6ms
# video 1/1 (frame 3228/3384) /content/Windmills.mp4: 192x288 8 0s, 11.6ms
# video 1/1 (frame 3229/3384) /content/Windmills.mp4: 192x288 9 0s, 10.2ms
# video 1/1 (frame 3230/3384) /content/Windmills.mp4: 192x288 2 0s, 10.3ms
# video 1/1 (frame 3231/3384) /content/Windmills.mp4: 192x288 5 0s, 15.3ms
# video 1/1 (frame 3232/3384) /content/Windmills.mp4: 192x288 4 0s, 9.4ms
# video 1/1 (frame 3233/3384) /content/Windmills.mp4: 192x288 6 0s, 10.6ms
# video 1/1 (frame 3234/3384) /content/Windmills.mp4: 192x288 6 0s, 10.6ms
# video 1/1 (frame 3235/3384) /content/Windmills.mp4: 192x288 3 0s, 9.7ms
# video 1/1 (frame 3236/3384) /content/Windmills.mp4: 192x288 6 0s, 11.1ms
# video 1/1 (frame 3237/3384) /content/Windmills.mp4: 192x288 6 0s, 8.5ms
# video 1/1 (frame 3238/3384) /content/Windmills.mp4: 192x288 6 0s, 11.0ms
# video 1/1 (frame 3239/3384) /content/Windmills.mp4: 192x288 6 0s, 12.0ms
# video 1/1 (frame 3240/3384) /content/Windmills.mp4: 192x288 4 0s, 8.9ms
# video 1/1 (frame 3241/3384) /content/Windmills.mp4: 192x288 4 0s, 22.7ms
# video 1/1 (frame 3242/3384) /content/Windmills.mp4: 192x288 4 0s, 9.5ms
# video 1/1 (frame 3243/3384) /content/Windmills.mp4: 192x288 4 0s, 9.9ms
# video 1/1 (frame 3244/3384) /content/Windmills.mp4: 192x288 4 0s, 9.7ms
# video 1/1 (frame 3245/3384) /content/Windmills.mp4: 192x288 3 0s, 11.1ms
# video 1/1 (frame 3246/3384) /content/Windmills.mp4: 192x288 4 0s, 9.7ms
# video 1/1 (frame 3247/3384) /content/Windmills.mp4: 192x288 3 0s, 9.5ms
# video 1/1 (frame 3248/3384) /content/Windmills.mp4: 192x288 4 0s, 9.6ms
# video 1/1 (frame 3249/3384) /content/Windmills.mp4: 192x288 4 0s, 8.4ms
# video 1/1 (frame 3250/3384) /content/Windmills.mp4: 192x288 3 0s, 9.3ms
# video 1/1 (frame 3251/3384) /content/Windmills.mp4: 192x288 3 0s, 9.2ms
# video 1/1 (frame 3252/3384) /content/Windmills.mp4: 192x288 5 0s, 12.5ms
# video 1/1 (frame 3253/3384) /content/Windmills.mp4: 192x288 5 0s, 9.2ms
# video 1/1 (frame 3254/3384) /content/Windmills.mp4: 192x288 6 0s, 9.8ms
# video 1/1 (frame 3255/3384) /content/Windmills.mp4: 192x288 7 0s, 9.8ms
# video 1/1 (frame 3256/3384) /content/Windmills.mp4: 192x288 7 0s, 9.8ms
# video 1/1 (frame 3257/3384) /content/Windmills.mp4: 192x288 7 0s, 9.3ms
# video 1/1 (frame 3258/3384) /content/Windmills.mp4: 192x288 7 0s, 8.7ms
# video 1/1 (frame 3259/3384) /content/Windmills.mp4: 192x288 6 0s, 8.9ms
# video 1/1 (frame 3260/3384) /content/Windmills.mp4: 192x288 7 0s, 11.8ms
# video 1/1 (frame 3261/3384) /content/Windmills.mp4: 192x288 6 0s, 8.4ms
# video 1/1 (frame 3262/3384) /content/Windmills.mp4: 192x288 7 0s, 8.8ms
# video 1/1 (frame 3263/3384) /content/Windmills.mp4: 192x288 6 0s, 10.8ms
# video 1/1 (frame 3264/3384) /content/Windmills.mp4: 192x288 5 0s, 8.6ms
# video 1/1 (frame 3265/3384) /content/Windmills.mp4: 192x288 5 0s, 8.8ms
# video 1/1 (frame 3266/3384) /content/Windmills.mp4: 192x288 5 0s, 9.4ms
# video 1/1 (frame 3267/3384) /content/Windmills.mp4: 192x288 5 0s, 8.5ms
# video 1/1 (frame 3268/3384) /content/Windmills.mp4: 192x288 5 0s, 9.0ms
# video 1/1 (frame 3269/3384) /content/Windmills.mp4: 192x288 5 0s, 8.3ms
# video 1/1 (frame 3270/3384) /content/Windmills.mp4: 192x288 5 0s, 9.8ms
# video 1/1 (frame 3271/3384) /content/Windmills.mp4: 192x288 7 0s, 10.8ms
# video 1/1 (frame 3272/3384) /content/Windmills.mp4: 192x288 8 0s, 9.4ms
# video 1/1 (frame 3273/3384) /content/Windmills.mp4: 192x288 7 0s, 9.1ms
# video 1/1 (frame 3274/3384) /content/Windmills.mp4: 192x288 7 0s, 8.3ms
# video 1/1 (frame 3275/3384) /content/Windmills.mp4: 192x288 6 0s, 13.1ms
# video 1/1 (frame 3276/3384) /content/Windmills.mp4: 192x288 6 0s, 9.2ms
# video 1/1 (frame 3277/3384) /content/Windmills.mp4: 192x288 5 0s, 15.8ms
# video 1/1 (frame 3278/3384) /content/Windmills.mp4: 192x288 4 0s, 9.7ms
# video 1/1 (frame 3279/3384) /content/Windmills.mp4: 192x288 5 0s, 9.8ms
# video 1/1 (frame 3280/3384) /content/Windmills.mp4: 192x288 4 0s, 10.0ms
# video 1/1 (frame 3281/3384) /content/Windmills.mp4: 192x288 4 0s, 12.1ms
# video 1/1 (frame 3282/3384) /content/Windmills.mp4: 192x288 4 0s, 10.5ms
# video 1/1 (frame 3283/3384) /content/Windmills.mp4: 192x288 4 0s, 10.1ms
# video 1/1 (frame 3284/3384) /content/Windmills.mp4: 192x288 6 0s, 9.7ms
# video 1/1 (frame 3285/3384) /content/Windmills.mp4: 192x288 4 0s, 9.0ms
# video 1/1 (frame 3286/3384) /content/Windmills.mp4: 192x288 4 0s, 8.5ms
# video 1/1 (frame 3287/3384) /content/Windmills.mp4: 192x288 4 0s, 9.9ms
# video 1/1 (frame 3288/3384) /content/Windmills.mp4: 192x288 4 0s, 8.8ms
# video 1/1 (frame 3289/3384) /content/Windmills.mp4: 192x288 4 0s, 9.2ms
# video 1/1 (frame 3290/3384) /content/Windmills.mp4: 192x288 5 0s, 10.4ms
# video 1/1 (frame 3291/3384) /content/Windmills.mp4: 192x288 3 0s, 8.9ms
# video 1/1 (frame 3292/3384) /content/Windmills.mp4: 192x288 4 0s, 8.6ms
# video 1/1 (frame 3293/3384) /content/Windmills.mp4: 192x288 4 0s, 9.5ms
# video 1/1 (frame 3294/3384) /content/Windmills.mp4: 192x288 4 0s, 9.0ms
# video 1/1 (frame 3295/3384) /content/Windmills.mp4: 192x288 6 0s, 13.5ms
# video 1/1 (frame 3296/3384) /content/Windmills.mp4: 192x288 6 0s, 9.2ms
# video 1/1 (frame 3297/3384) /content/Windmills.mp4: 192x288 6 0s, 9.4ms
# video 1/1 (frame 3298/3384) /content/Windmills.mp4: 192x288 7 0s, 9.2ms
# video 1/1 (frame 3299/3384) /content/Windmills.mp4: 192x288 7 0s, 9.5ms
# video 1/1 (frame 3300/3384) /content/Windmills.mp4: 192x288 7 0s, 8.9ms
# video 1/1 (frame 3301/3384) /content/Windmills.mp4: 192x288 6 0s, 9.5ms
# video 1/1 (frame 3302/3384) /content/Windmills.mp4: 192x288 6 0s, 9.1ms
# video 1/1 (frame 3303/3384) /content/Windmills.mp4: 192x288 6 0s, 9.9ms
# video 1/1 (frame 3304/3384) /content/Windmills.mp4: 192x288 5 0s, 8.3ms
# video 1/1 (frame 3305/3384) /content/Windmills.mp4: 192x288 7 0s, 9.3ms
# video 1/1 (frame 3306/3384) /content/Windmills.mp4: 192x288 7 0s, 9.5ms
# video 1/1 (frame 3307/3384) /content/Windmills.mp4: 192x288 6 0s, 9.1ms
# video 1/1 (frame 3308/3384) /content/Windmills.mp4: 192x288 5 0s, 9.4ms
# video 1/1 (frame 3309/3384) /content/Windmills.mp4: 192x288 5 0s, 9.2ms
# video 1/1 (frame 3310/3384) /content/Windmills.mp4: 192x288 5 0s, 11.3ms
# video 1/1 (frame 3311/3384) /content/Windmills.mp4: 192x288 5 0s, 8.7ms
# video 1/1 (frame 3312/3384) /content/Windmills.mp4: 192x288 5 0s, 9.5ms
# video 1/1 (frame 3313/3384) /content/Windmills.mp4: 192x288 7 0s, 10.2ms
# video 1/1 (frame 3314/3384) /content/Windmills.mp4: 192x288 5 0s, 9.5ms
# video 1/1 (frame 3315/3384) /content/Windmills.mp4: 192x288 5 0s, 9.5ms
# video 1/1 (frame 3316/3384) /content/Windmills.mp4: 192x288 5 0s, 8.8ms
# video 1/1 (frame 3317/3384) /content/Windmills.mp4: 192x288 5 0s, 10.9ms
# video 1/1 (frame 3318/3384) /content/Windmills.mp4: 192x288 5 0s, 8.3ms
# video 1/1 (frame 3319/3384) /content/Windmills.mp4: 192x288 (no detections), 9.0ms
# video 1/1 (frame 3320/3384) /content/Windmills.mp4: 192x288 (no detections), 8.3ms
# video 1/1 (frame 3321/3384) /content/Windmills.mp4: 192x288 (no detections), 8.7ms
# video 1/1 (frame 3322/3384) /content/Windmills.mp4: 192x288 (no detections), 8.4ms
# video 1/1 (frame 3323/3384) /content/Windmills.mp4: 192x288 (no detections), 9.0ms
# video 1/1 (frame 3324/3384) /content/Windmills.mp4: 192x288 (no detections), 8.5ms
# video 1/1 (frame 3325/3384) /content/Windmills.mp4: 192x288 (no detections), 8.3ms
# video 1/1 (frame 3326/3384) /content/Windmills.mp4: 192x288 (no detections), 9.4ms
# video 1/1 (frame 3327/3384) /content/Windmills.mp4: 192x288 (no detections), 8.8ms
# video 1/1 (frame 3328/3384) /content/Windmills.mp4: 192x288 (no detections), 13.9ms
# video 1/1 (frame 3329/3384) /content/Windmills.mp4: 192x288 (no detections), 8.9ms
# video 1/1 (frame 3330/3384) /content/Windmills.mp4: 192x288 (no detections), 8.8ms
# video 1/1 (frame 3331/3384) /content/Windmills.mp4: 192x288 (no detections), 8.0ms
# video 1/1 (frame 3332/3384) /content/Windmills.mp4: 192x288 (no detections), 8.4ms
# video 1/1 (frame 3333/3384) /content/Windmills.mp4: 192x288 (no detections), 9.0ms
# video 1/1 (frame 3334/3384) /content/Windmills.mp4: 192x288 (no detections), 8.5ms
# video 1/1 (frame 3335/3384) /content/Windmills.mp4: 192x288 (no detections), 8.3ms
# video 1/1 (frame 3336/3384) /content/Windmills.mp4: 192x288 (no detections), 8.3ms
# video 1/1 (frame 3337/3384) /content/Windmills.mp4: 192x288 (no detections), 9.3ms
# video 1/1 (frame 3338/3384) /content/Windmills.mp4: 192x288 (no detections), 8.8ms
# video 1/1 (frame 3339/3384) /content/Windmills.mp4: 192x288 (no detections), 8.1ms
# video 1/1 (frame 3340/3384) /content/Windmills.mp4: 192x288 (no detections), 8.4ms
# video 1/1 (frame 3341/3384) /content/Windmills.mp4: 192x288 (no detections), 8.2ms
# video 1/1 (frame 3342/3384) /content/Windmills.mp4: 192x288 (no detections), 12.5ms
# video 1/1 (frame 3343/3384) /content/Windmills.mp4: 192x288 (no detections), 8.3ms
# video 1/1 (frame 3344/3384) /content/Windmills.mp4: 192x288 (no detections), 8.6ms
# video 1/1 (frame 3345/3384) /content/Windmills.mp4: 192x288 (no detections), 8.4ms
# video 1/1 (frame 3346/3384) /content/Windmills.mp4: 192x288 (no detections), 9.6ms
# video 1/1 (frame 3347/3384) /content/Windmills.mp4: 192x288 (no detections), 8.8ms
# video 1/1 (frame 3348/3384) /content/Windmills.mp4: 192x288 (no detections), 8.5ms
# video 1/1 (frame 3349/3384) /content/Windmills.mp4: 192x288 1 0, 8.7ms
# video 1/1 (frame 3350/3384) /content/Windmills.mp4: 192x288 1 0, 8.6ms
# video 1/1 (frame 3351/3384) /content/Windmills.mp4: 192x288 1 0, 10.7ms
# video 1/1 (frame 3352/3384) /content/Windmills.mp4: 192x288 1 0, 11.6ms
# video 1/1 (frame 3353/3384) /content/Windmills.mp4: 192x288 1 0, 8.2ms
# video 1/1 (frame 3354/3384) /content/Windmills.mp4: 192x288 1 0, 8.9ms
# video 1/1 (frame 3355/3384) /content/Windmills.mp4: 192x288 1 0, 8.3ms
# video 1/1 (frame 3356/3384) /content/Windmills.mp4: 192x288 1 0, 14.1ms
# video 1/1 (frame 3357/3384) /content/Windmills.mp4: 192x288 1 0, 8.7ms
# video 1/1 (frame 3358/3384) /content/Windmills.mp4: 192x288 1 0, 9.2ms
# video 1/1 (frame 3359/3384) /content/Windmills.mp4: 192x288 1 0, 8.4ms
# video 1/1 (frame 3360/3384) /content/Windmills.mp4: 192x288 1 0, 9.7ms
# video 1/1 (frame 3361/3384) /content/Windmills.mp4: 192x288 1 0, 8.4ms
# video 1/1 (frame 3362/3384) /content/Windmills.mp4: 192x288 (no detections), 9.2ms
# video 1/1 (frame 3363/3384) /content/Windmills.mp4: 192x288 (no detections), 8.6ms
# video 1/1 (frame 3364/3384) /content/Windmills.mp4: 192x288 (no detections), 10.5ms
# video 1/1 (frame 3365/3384) /content/Windmills.mp4: 192x288 (no detections), 8.5ms
# video 1/1 (frame 3366/3384) /content/Windmills.mp4: 192x288 1 0, 8.3ms
# video 1/1 (frame 3367/3384) /content/Windmills.mp4: 192x288 1 0, 12.3ms
# video 1/1 (frame 3368/3384) /content/Windmills.mp4: 192x288 1 0, 8.4ms
# video 1/1 (frame 3369/3384) /content/Windmills.mp4: 192x288 1 0, 8.6ms
# video 1/1 (frame 3370/3384) /content/Windmills.mp4: 192x288 (no detections), 8.2ms
# video 1/1 (frame 3371/3384) /content/Windmills.mp4: 192x288 2 0s, 9.7ms
# video 1/1 (frame 3372/3384) /content/Windmills.mp4: 192x288 (no detections), 8.5ms
# video 1/1 (frame 3373/3384) /content/Windmills.mp4: 192x288 (no detections), 8.8ms
# video 1/1 (frame 3374/3384) /content/Windmills.mp4: 192x288 (no detections), 8.9ms
# video 1/1 (frame 3375/3384) /content/Windmills.mp4: 192x288 (no detections), 8.6ms
# video 1/1 (frame 3376/3384) /content/Windmills.mp4: 192x288 (no detections), 9.5ms
# video 1/1 (frame 3377/3384) /content/Windmills.mp4: 192x288 (no detections), 8.4ms
# video 1/1 (frame 3378/3384) /content/Windmills.mp4: 192x288 (no detections), 8.7ms
# video 1/1 (frame 3379/3384) /content/Windmills.mp4: 192x288 (no detections), 11.6ms
# video 1/1 (frame 3380/3384) /content/Windmills.mp4: 192x288 (no detections), 16.1ms
# video 1/1 (frame 3381/3384) /content/Windmills.mp4: 192x288 (no detections), 8.5ms
# video 1/1 (frame 3382/3384) /content/Windmills.mp4: 192x288 (no detections), 8.9ms
# video 1/1 (frame 3383/3384) /content/Windmills.mp4: 192x288 (no detections), 8.8ms
# video 1/1 (frame 3384/3384) /content/Windmills.mp4: 192x288 (no detections), 9.2ms
# Speed: 1.0ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 192, 288)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[:3]:
    display(IPyImage(filename=img, width=600))
    print("\n")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv11 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv11 weights.

# %%
project.version(dataset.version).deploy(model_type="yolov11", model_path=f"{HOME}/runs/detect/train/")
# Out:
# View the status of your deployment at: https://app.roboflow.com/ismetgocer/windmills-bhea9/1
# Share your model with the world at: https://universe.roboflow.com/ismetgocer/windmills-bhea9/model/1

# %%
# !pip install inference

# %%
import os, random, cv2
import supervision as sv
import IPython
import inference

model_id = project.id.split("/")[1] + "/" + dataset.version
model = inference.get_model(model_id, userdata.get('ROBOFLOW_API_KEY'))

# Location of test set images
test_set_loc = dataset.location + "/test/images/"
test_images = os.listdir(test_set_loc)

# Run inference on 4 random test images, or fewer if fewer images are available
for img_name in random.sample(test_images, min(4, len(test_images))):
    print("Running inference on " + img_name)

    # Load image
    image = cv2.imread(os.path.join(test_set_loc, img_name))

    # Perform inference
    results = model.infer(image, confidence=0.4, overlap=30)[0]
    detections = sv.Detections.from_inference(results)

    # Annotate boxes and labels
    box_annotator = sv.BoxAnnotator()
    label_annotator = sv.LabelAnnotator()
    annotated_image = box_annotator.annotate(scene=image, detections=detections)
    annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

    # Display annotated image
    _, ret = cv2.imencode('.jpg', annotated_image)
    i = IPython.display.Image(data=ret)
    IPython.display.display(i)

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.

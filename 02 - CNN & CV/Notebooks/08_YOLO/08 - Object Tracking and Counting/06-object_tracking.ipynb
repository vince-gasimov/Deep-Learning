# %% [markdown]
# # YOLOv11 Object Tracking

# %% [markdown]
# **It is recommended to perform the operations with GPU.**

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/B287/CNN/Object Tracking
# Out:
# /content/drive/MyDrive/B287/CNN/Object Tracking

# %%
pwd
# Out:
# '/content/drive/MyDrive/B287/CNN/Object Tracking'

# %%
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.175 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.1/112.6 GB disk)

# %% [markdown]
# **NOTE: You can download a video for testing from a free platform as follows: Search: car**
#
# https://pixabay.com/videos/cars-motorway-speed-motion-traffic-1900/
#
# **Alternative video:**
#
# https://pixabay.com/videos/vehicle-car-automobile-139809

# %% [markdown]
# ## Tracking (Model Test)

# %% [markdown]
# ## Object Tracking with Pre-trained model:

# %%
# The code can be taken from the CLI section of the following address:
# https://docs.ultralytics.com/tr/modes/track/#__tabbed_1_2
# Example video is inside the `Object_tracking_counting` folder in the `data` folder on Google Drive.
# You can also provide a YouTube link for the `source` part.
# !yolo track model=yolo11n.pt source="data/test.mp4"
# The model, trained with the COCO dataset, analyzes each scene below.
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 0.6s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# Ultralytics 8.3.175 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# video 1/1 (frame 1/1501) /content/drive/MyDrive/B287/CNN/Object Tracking/data/test.mp4: 384x640 8 cars, 2 buss, 2 trucks, 1 traffic light, 49.6ms
# video 1/1 (frame 2/1501) /content/drive/MyDrive/B287/CNN/Object Tracking/data/test.mp4: 384x640 8 cars, 2 buss, 1 traffic light, 17.1ms
# video 1/1 (frame 3/1501) /content/drive/MyDrive/B287/CNN/Object Tracking/data/test.mp4: 384x640 8 cars, 2 buss, 1 traffic light, 16.2ms
# video 1/1 (frame 4/1501) /content/drive/MyDrive/B287/CNN/Object Tracking/data/test.mp4: 384x640 8 cars, 2 buss, 1 traffic light, 13.6ms
# ...

# %%
# The results of the above are in the `runs/detect/track` directory.
# You can also check this by going to the corresponding folder in Google Drive.
# Alternatively, you can navigate to the relevant directory in the folder structure on the left.
# You will find the `test.avi` file. You can download and review the file.
# The result video will have assigned an ID number to each vehicle.

# %% [markdown]
# ## Object tracking with a custom model

# %%
# In tracking, there are two types of trackers. The Bot-track was used above because it is the default model.
# Below is an explanation of these two trackers. Additionally, results were obtained using another tracker model further down.

# %% [markdown]
# **Tracking methods used in YOLO: ByteTrack and BoT-SORT (or BoT-Track)**
#
# ### 1. **What is ByteTrack?**
#
# * **ByteTrack** is a next-generation algorithm developed for real-time object tracking (Multi-Object Tracking, MOT).
# * It can be used in conjunction with object detection models like **YOLO**.
# * **Biggest innovation:** It considers both high-confidence and low-confidence detections, allowing it to track objects that might be missed in previous methods.
# * **How it works:**
#
#   * Matches all detections (high and low confidence) in two phases.
#   * First, it matches existing tracks with high-confidence detections.
#   * Then, it matches unmatched tracks with low-confidence detections.
# * **Advantage:** It performs well in scenarios with crowded or occluded objects, better tracking of slow-moving or temporarily disappearing objects.
# * **Use cases:** It is particularly useful in video surveillance, traffic analysis, and human/vehicle tracking applications.
#
# ---
#
# ### 2. **What is BoT-SORT / BoT-Track?**
#
# * **BoT-SORT (also known as BoT-Track)** is an advanced, optimized version of the SORT algorithm.
# * **SORT (Simple Online and Realtime Tracking):** Traditionally tracks the position and speed of object centers.
# * **Difference of BoT-SORT:**
#
#   * It not only uses positional information (bounding box) for tracking but also incorporates **visual (appearance) features**.
#   * **ReID (Re-Identification) feature**: Can recognize the same object when it reappears after being lost.
#   * **Strong Data Association:** More accurate track matching is done with location + visual features.
# * **How it works:**
#
#   * A visual attribute (embedding) is extracted for each object.
#   * During tracking, both box position and these embeddings are used for matching.
# * **Advantage:** It reduces track loss, especially for short-term disappearing, similar, or overlapping objects, providing more stable tracking.
# * **Use cases:** It is used for long-term tracking of multiple similar objects like pedestrians, vehicles, and animals.
#
# ---
#
# **Conclusion**
#
# * **ByteTrack:** Score-based matching, low loss, real-time.
# * **BoT-SORT:** Visual similarity, prevents ID confusion, more stable long-term tracking.
#
# When integrated with YOLO, both algorithms are used as industry standards for real-time video analysis and object tracking applications.

# %%
# !yolo track model=yolov8n.pt source="data/test.mp4" tracker="bytetrack.yaml" # Byte-Track, BoT-Track

# In tracking, the default model is the Bot-track model.** There is no need to specify it when using. Here, the Byte-track method was used.
# Out:
# Ultralytics 8.3.175 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (frame 1/1501) /content/drive/MyDrive/B287/CNN/Object Tracking/data/test.mp4: 384x640 7 cars, 1 bus, 2 trucks, 42.5ms
# video 1/1 (frame 2/1501) /content/drive/MyDrive/B287/CNN/Object Tracking/data/test.mp4: 384x640 7 cars, 1 bus, 2 trucks, 7.2ms
# video 1/1 (frame 3/1501) /content/drive/MyDrive/B287/CNN/Object Tracking/data/test.mp4: 384x640 7 cars, 2 buss, 6.6ms
# video 1/1 (frame 4/1501) /content/drive/MyDrive/B287/CNN/Object Tracking/data/test.mp4: 384x640 7 cars, 2 buss, 6.6ms
# video 1/1 (frame 5/1501) /content/drive/MyDrive/B287/CNN/Object Tracking/data/test.mp4: 384x640 7 cars, 2 buss, 6.4ms
# video 1/1 (frame 6/1501) /content/drive/MyDrive/B287/CNN/Object Tracking/data/test.mp4: 384x640 6 cars, 2 buss, 1 truck, 6.4ms
# ...

# %%
# We can view the results of the above work in the `runs/detect/track2` folder.

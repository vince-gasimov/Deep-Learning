# %% [markdown]
# ## YOLOv11 | Pretrained Model Comparison

# %%
# This NB should be executed in Colab

# %% [markdown]
# Source:
# - https://docs.ultralytics.com/
# - https://cocodataset.org/#home
# - https://github.com/ultralytics/ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison
# Out:
# /content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison

# %%
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.159 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 41.5/235.7 GB disk)

# %%
# In YOLOv11, just like in YOLOv8, the model file is not downloaded with a single line of code!!

# For this, go to the following link: 
# [https://docs.ultralytics.com/models/yolo11/#performance-metrics]
# (https://docs.ultralytics.com/models/yolo11/#performance-metrics), d
# ownload the model files one by one, and copy them to the relevant folder in Colab.

# %% [markdown]
# # mAP

# %%
# !yolo detect val model="/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/yolo11n.pt" data=coco128.yaml iou=0.5 name=yolov11n_test  #iou=threshold value
# Out:
# Ultralytics 8.3.159 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 126MB/s]
# val: Fast image access ✅ (ping: 0.5±0.1 ms, read: 9.7±21.7 MB/s, size: 51.4 KB)
# val: Scanning /content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/datasets/coco128/labels/train2017... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:13<00:00,  9.31it/s]
# val: New cache created: /content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/datasets/coco128/labels/train2017.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:03<00:00,  2.60it/s]
#                    all        128        929      0.686      0.603      0.684      0.504
#                 person         61        254      0.819      0.705      0.807      0.544
# ...

# %%
# !yolo detect val model="/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/yolo11s.pt" data=coco128.yaml iou=0.5 name=yolov11s_test
# Out:
# Ultralytics 8.3.159 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11s summary (fused): 100 layers, 9,443,760 parameters, 0 gradients, 21.5 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.1 ms, read: 66.6±39.2 MB/s, size: 65.9 KB)
# val: Scanning /content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:02<00:00,  3.96it/s]
#                    all        128        929      0.732      0.699      0.754      0.572
#                 person         61        254      0.863      0.717      0.828        0.6
#                bicycle          3          6      0.534      0.333      0.385      0.313
#                    car         12         46      0.757      0.271      0.446      0.254
# ...

# %%
# !yolo detect val model="/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/yolo11m.pt" data=coco128.yaml iou=0.5 name=yolov11m_test
# Out:
# Ultralytics 8.3.159 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11m summary (fused): 125 layers, 20,091,712 parameters, 0 gradients, 68.0 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 55.5±23.5 MB/s, size: 57.3 KB)
# val: Scanning /content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:02<00:00,  3.90it/s]
#                    all        128        929      0.814      0.691        0.8      0.616
#                 person         61        254      0.916      0.693      0.847      0.648
#                bicycle          3          6          1      0.626      0.763      0.564
#                    car         12         46      0.911      0.261      0.487      0.306
# ...

# %%
# !yolo detect val model="/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/yolo11l.pt" data=coco128.yaml iou=0.5 name=yolov11l_test
# Out:
# Ultralytics 8.3.159 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11l summary (fused): 190 layers, 25,340,992 parameters, 0 gradients, 86.9 GFLOPs
# val: Fast image access ✅ (ping: 4.8±9.8 ms, read: 20.7±26.0 MB/s, size: 59.3 KB)
# val: Scanning /content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:02<00:00,  3.77it/s]
#                    all        128        929      0.739      0.757      0.802      0.629
#                 person         61        254      0.881      0.756      0.869       0.66
#                bicycle          3          6          1       0.49      0.594      0.464
#                    car         12         46      0.824      0.305       0.55      0.332
# ...

# %%
# !yolo detect val model="/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/yolo11x.pt" data=coco128.yaml iou=0.5 name=yolov11x_test
# Out:
# Ultralytics 8.3.159 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11x summary (fused): 190 layers, 56,919,424 parameters, 0 gradients, 194.9 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.2 ms, read: 32.6±15.4 MB/s, size: 42.9 KB)
# val: Scanning /content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:02<00:00,  3.65it/s]
#                    all        128        929      0.827      0.741      0.855      0.694
#                 person         61        254      0.933      0.717       0.88      0.682
#                bicycle          3          6          1      0.506       0.84      0.678
#                    car         12         46      0.933      0.304      0.668      0.384
# ...

# %% [markdown]
# # FPS

# %% [markdown]
# The `helper.py` file in the folder will read the video and display the FPS value on it. Just having it in the folder is enough.

# %% [markdown]
# Each YOLOv11 model will be processed separately, and a new file will be created for each. These files will be inside the "results" folder in Google Drive.

# %%
from helper import process_video

# %% [markdown]
# YOLOv11n

# %%
video_path = "/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/inference/test.mp4"
save_path = "./results/test_yolov11n_result.mp4"

model_path = "/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/yolo11n.pt"

image_size = 320
half_precision = False

process_video(video_path, model_path, save_path, image_size, half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov11n_result.mp4

# %% [markdown]
# YOLOv11s

# %%
video_path = "/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/inference/test.mp4"
save_path = "./results/test_yolov11s_result.mp4"

model_path = "/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/yolo11s.pt"

image_size = 320
half_precision = False

process_video(video_path, model_path, save_path, image_size, half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov11s_result.mp4

# %% [markdown]
# YOLOv11m

# %%
video_path = "/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/inference/test.mp4"
save_path = "./results/test_yolov11m_result.mp4"

model_path = "/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/yolo11m.pt"

image_size = 320
half_precision = False

process_video(video_path, model_path, save_path, image_size, half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov11m_result.mp4

# %% [markdown]
# YOLOv11l

# %%
video_path = "/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/inference/test.mp4"
save_path = "./results/test_yolov11l_result.mp4"

model_path = "/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/yolo11l.pt"

image_size = 320
half_precision = False

process_video(video_path, model_path, save_path, image_size, half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov11l_result.mp4

# %% [markdown]
# YOLOv11x

# %%
video_path = "/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/inference/test.mp4"
save_path = "./results/test_yolov11x_result.mp4"

model_path = "/content/drive/MyDrive/CNN-CV Lesson/YOLO_model_comparison/yolo11x.pt"

image_size = 320
half_precision = False

process_video(video_path, model_path, save_path, image_size, half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov11x_result.mp4

# %%
# We can download each video from the "Results" folder in Google Drive, watch the video, and note down the approximate highest FPS achieved...
# Let's record these in the "comparison" file. We will compare the results here.

# %%
# FPS can be preferred for faster performance, but its mAP value may be lower...
# Models with an FPS value above 30 are usable. A model with the highest mAP value but an FPS in the 2nd or 3rd place 
# (if they are close to each other) will be considered an acceptable model.

# %% [markdown]
# ![image.png](attachment:ba169954-4921-4540-a7a1-bbbcfc1bcb43.png)

# %% [markdown]
# ## YOLOv11 | Pretrained Model Comparison

# %%
# This NB should be executed in Colab

# %% [markdown]
# Source:
# - https://docs.ultralytics.com/
# - https://cocodataset.org/#home
# - https://github.com/ultralytics/ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison
# os.chdir()
# Out:
# /content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison

# %%
pwd # print working directory
# Out:
# '/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison'

# %%
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.0/112.6 GB disk)

# %%
# In YOLOv11, just like in YOLOv8, the model file is not downloaded with a single line of code!!

# For this, go to the following link:
# [https://docs.ultralytics.com/models/yolo11/#performance-metrics]
# (https://docs.ultralytics.com/models/yolo11/#performance-metrics),
# download the model files one by one, and copy them to the relevant folder in Colab.

# %% [markdown]
# # mAP

# %%
# !yolo detect val model="/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/yolo11n.pt" data=coco128.yaml iou=0.5 name=yolov11n_test  #iou=threshold value
# Out:
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# val: Fast image access ✅ (ping: 7.4±14.5 ms, read: 17.2±17.8 MB/s, size: 62.2 KB)
# val: Scanning /content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 128/128 16.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.9it/s 2.8s
#                    all        128        929      0.686      0.603      0.681      0.501
#                 person         61        254      0.819      0.705      0.804      0.535
#                bicycle          3          6      0.377      0.167      0.461      0.269
#                    car         12         46      0.663      0.196      0.239      0.148
# ...

# %%
# !yolo detect val model="/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/yolo11s.pt" data=coco128.yaml iou=0.5 name=yolov11s_test
# Out:
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 100 layers, 9,443,760 parameters, 0 gradients, 21.5 GFLOPs
# val: Fast image access ✅ (ping: 1.1±0.5 ms, read: 10.7±5.0 MB/s, size: 38.2 KB)
# val: Scanning /content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 128/128 17.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.8it/s 2.9s
#                    all        128        929      0.732      0.699      0.751      0.567
#                 person         61        254      0.863      0.716      0.822       0.59
#                bicycle          3          6      0.534      0.333      0.383       0.31
#                    car         12         46      0.757      0.271      0.438      0.247
# ...

# %%
# !yolo detect val model="/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/yolo11m.pt" data=coco128.yaml iou=0.5 name=yolov11m_test
# Out:
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11m summary (fused): 125 layers, 20,091,712 parameters, 0 gradients, 68.0 GFLOPs
# val: Fast image access ✅ (ping: 0.7±0.3 ms, read: 30.9±16.3 MB/s, size: 43.3 KB)
# val: Scanning /content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 128/128 23.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.0it/s 4.0s
#                    all        128        929      0.814      0.691      0.797      0.609
#                 person         61        254      0.916      0.693      0.841      0.636
#                bicycle          3          6          1      0.626      0.759      0.559
#                    car         12         46      0.911      0.261      0.476      0.295
# ...

# %%
# !yolo detect val model="/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/yolo11l.pt" data=coco128.yaml iou=0.5 name=yolov11l_test
# Out:
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11l summary (fused): 190 layers, 25,340,992 parameters, 0 gradients, 86.9 GFLOPs
# val: Fast image access ✅ (ping: 0.6±0.3 ms, read: 18.3±16.1 MB/s, size: 52.5 KB)
# val: Scanning /content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 128/128 14.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.7it/s 4.6s
#                    all        128        929      0.739      0.757      0.798      0.622
#                 person         61        254      0.881      0.756      0.864      0.647
#                bicycle          3          6          1       0.49      0.591       0.46
#                    car         12         46      0.825      0.308      0.535      0.317
# ...

# %%
# !yolo detect val model="/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/yolo11x.pt" data=coco128.yaml iou=0.5 name=yolov11x_test
# Out:
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11x summary (fused): 190 layers, 56,919,424 parameters, 0 gradients, 194.9 GFLOPs
# val: Fast image access ✅ (ping: 0.9±0.4 ms, read: 20.9±10.4 MB/s, size: 47.3 KB)
# val: Scanning /content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 128/128 24.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.1it/s 7.1s
#                    all        128        929      0.827      0.742      0.851      0.686
#                 person         61        254      0.933      0.717      0.875      0.668
#                bicycle          3          6          1      0.508      0.835      0.672
#                    car         12         46      0.933      0.303      0.659       0.37
# ...

# %% [markdown]
# # FPS

# %% [markdown]
# The `helper.py` file in the folder will read the video and display the FPS value on it. Just having it in the folder is enough.

# %% [markdown]
# Each YOLOv11 model will be processed separately, and a new file will be created for each. These files will be inside the "results" folder in Google Drive.

# %%
from helper import process_video

# %% [markdown]
# YOLOv11n

# %%
video_path = "/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/inference/test.mp4"
save_path = "./results/test_yolov11n_result.mp4"

model_path = "/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/yolo11n.pt"

image_size = 320
half_precision = False

process_video(video_path, model_path, save_path, image_size, half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov11n_result.mp4

# %% [markdown]
# YOLOv11s

# %%
video_path = "/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/inference/test.mp4"
save_path = "./results/test_yolov11s_result.mp4"

model_path = "/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/yolo11s.pt"

image_size = 320
half_precision = False

process_video(video_path, model_path, save_path, image_size, half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov11s_result.mp4

# %% [markdown]
# YOLOv11m

# %%
video_path = "/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/inference/test.mp4"
save_path = "./results/test_yolov11m_result.mp4"

model_path = "/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/yolo11m.pt"

image_size = 320
half_precision = False

process_video(video_path, model_path, save_path, image_size, half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov11m_result.mp4

# %% [markdown]
# YOLOv11l

# %%
video_path = "/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/inference/test.mp4"
save_path = "./results/test_yolov11l_result.mp4"

model_path = "/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/yolo11l.pt"

image_size = 320
half_precision = False

process_video(video_path, model_path, save_path, image_size, half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov11l_result.mp4

# %% [markdown]
# YOLOv11x

# %%
video_path = "/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/inference/test.mp4"
save_path = "./results/test_yolov11x_result.mp4"

model_path = "/content/drive/MyDrive/CNN - CV NBs and DataSets/CNN/Model Comparison/yolo11x.pt"

image_size = 320
half_precision = False

process_video(video_path, model_path, save_path, image_size, half_precision)
# Out:
# [INFO]: Video is processing..
# [INFO]: Processing task is completed successfully!..
# Result video is saved in: ./results/test_yolov11x_result.mp4

# %%
# We can download each video from the "Results" folder in Google Drive, watch the video, and note down the approximate highest FPS achieved...
# Let's record these in the "comparison" file. We will compare the results here.

# %%
# FPS can be preferred for faster performance, but its mAP value may be lower...
# Models with an FPS value above 30 are usable. A model with the highest mAP value but an FPS in the 2nd or 3rd place
# (if they are close to each other) will be considered an acceptable model.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

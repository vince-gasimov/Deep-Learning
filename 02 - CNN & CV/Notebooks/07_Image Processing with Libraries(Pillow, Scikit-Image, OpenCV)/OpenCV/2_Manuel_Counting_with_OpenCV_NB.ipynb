# %% [markdown]
# # Counting NB

# %%
# Necessary
# !pip install cvlib

# %%
#pip install --upgrade cvlib opencv-python numpy matplotlib

# %%
#pip install --upgrade opencv-python cvlib

# %%
#pip install --upgrade opencv-python cvlib

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
from numpy.lib.polynomial import poly
# Out:
# WARNING:tensorflow:From C:\Users\ismet\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Original Images
img= cv2.imread("cats.jpg")
img1=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.axis("off")
plt.imshow(img1)
plt.show()

# %% [markdown]
# ![%7B05963C28-7F0C-4D60-9F51-44BB66EC4C63%7D.png](attachment:%7B05963C28-7F0C-4D60-9F51-44BB66EC4C63%7D.png)

# %% [markdown]
# ![%7BD2DE1C5E-7879-4399-93C0-90460C656F6E%7D.png](attachment:%7BD2DE1C5E-7879-4399-93C0-90460C656F6E%7D.png)

# %%
# Bounding Boxes
box, label, count = cv.detect_common_objects (img) 
output = draw_bbox(img, box, label, count)
output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.axis("off")
plt.imshow(output)
plt.show()

# %% [markdown]
# ![%7B8A5555B4-B513-4DD0-8549-DF408BF9F6F2%7D.png](attachment:%7B8A5555B4-B513-4DD0-8549-DF408BF9F6F2%7D.png)

# %% [markdown]
# ![%7B3A06D148-B3B8-424D-A2CC-C919813DD411%7D.png](attachment:%7B3A06D148-B3B8-424D-A2CC-C919813DD411%7D.png)

# %%
# Count
print("Number of objects in this image are: " +str(len(label)))
# Out:
# Number of objects in this image are: 6

# %% [markdown]
# ![%7B820813A4-4117-44E8-AB10-AC32188D6CDE%7D.png](attachment:%7B820813A4-4117-44E8-AB10-AC32188D6CDE%7D.png)

# %%
# original Image
imge= cv2.imread("cars.jpg")
imge1=cv2.cvtColor(imge, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.axis("off")
plt.imshow(imge1)
plt.show()

# %%
# Bounding Boxes
box, label, count = cv.detect_common_objects (imge) 
output = draw_bbox(imge, box, label, count)
output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.axis("off")
plt.imshow(output)
plt.show()

# %%
# Count
print("Number of objects in this image are: " +str(len(label)))
# Out:
# Number of objects in this image are: 16

# %%
label.count("car")
# Out:
# 14

# %%
label.count("truck")
# Out:
# 2

# %%
# Orginal Image
im= cv2.imread("trees.jpg")
im1=cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.axis("off")
plt.imshow(im1)
plt.show()

# %%
# Bounding Boxes
box, label, count = cv.detect_common_objects (im) 
output = draw_bbox(im, box, label, count)
output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.axis("off")
plt.imshow(output)
plt.show()

# %%
# Number
print("Number of objects in this image are: " +str(len(label)))
# Out:
# Number of objects in this image are: 0

# %% [markdown]
# * As you can see, this code **could not do the counting process completely**, we will see a **more advanced version** of it in the **next notebook**.

# %%
# Original Image
picture= cv2.imread("planes.jpg")
imge1=cv2.cvtColor(picture, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.axis("off")
plt.imshow(imge1)
plt.show()

# %%
# Bounding Box
box, label, count = cv.detect_common_objects (picture) 
output = draw_bbox(picture, box, label, count)
output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.axis("off")
plt.imshow(output)
plt.show()

# %%
# Count
print("Number of planes in this image are: " +str(len(label)))
# Out:
# Number of planes in this image are: 5

# %%
# DONE

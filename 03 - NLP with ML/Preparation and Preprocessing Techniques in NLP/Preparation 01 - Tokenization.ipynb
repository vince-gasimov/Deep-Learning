# %%
# !pip install nltk

# %%
corpus="""Hello, Welcome to Data Science Bootcamp's NLP Tutorials.
Please do watch the entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello, Welcome to Data Science Bootcamp's NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.

# %% [markdown]
# #### Sentence Tokenizater
#
# ##### paragraphs -->> sentence

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ["Hello, Welcome to Data Science Bootcamp's NLP Tutorials.",
#  'Please do watch the entire course!',
#  'to become expert in NLP.']

# %%
documents = sent_tokenize(corpus)
documents
# Out:
# ["Hello, Welcome to Data Science Bootcamp's NLP Tutorials.",
#  'Please do watch the entire course!',
#  'to become expert in NLP.']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello, Welcome to Data Science Bootcamp's NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP.

# %% [markdown]
# #### Word Tokenizer
#
# ##### paragraphs, sentences --> words

# %%
from nltk.tokenize import word_tokenize

# %%
documents = word_tokenize(corpus)
documents
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'to',
#  'Data',
#  'Science',
#  'Bootcamp',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for word in documents:
    print(word)
# Out:
# Hello
# ,
# Welcome
# to
# Data
# Science
# Bootcamp
# 's
# NLP
# Tutorials
# .
# Please
# do
# watch
# the
# entire
# course
# !
# to
# become
# expert
# in
# NLP
# .

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
documents = wordpunct_tokenize(corpus)
documents
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'to',
#  'Data',
#  'Science',
#  'Bootcamp',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'to',
#  'Data',
#  'Science',
#  'Bootcamp',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
